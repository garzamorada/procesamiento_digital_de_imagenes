# %% [markdown]
# # Generador de palabras para OCR
# Herramienta para generar dataset de imagenes sinteticas de fuentes

# %% [markdown]
# ## Importación de Librerias

# %%
#Importo librerias a utilizar
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import shutil
import re
import cv2
import random
from PIL import Image, ImageFilter, ImageDraw, ImageFont
from IPython.display import Image as ImageDisplay
from IPython.core.display import HTML
from io import BytesIO
import base64

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Variables de configuracion
archivo_zip_fuentes = '/content/drive/MyDrive/tp_integrador/fuentes.zip'
carpeta_destino = '/content/fuentes'
cantidad_de_repeticiones = 2 # Cantidad de repeticiones por letra y fuente
largo_minimo_palabra = 1 # cantidad minima de caracteres por palabra
largo_maximo_palabra = 4 # cantidad maxima de caracteres por palabra
maximo_palabras_imagen = 3 # cantidad maxima de palabras por imagen * 1 palabra por linea
carpeta_destino_datasets = '/content/datasets'
rango_separacion_caracteres = (1,5)
rango_separacion_lineas = (10,40)
rango_tamanio_fuente = (24,48)
tamanio_imagen = 256 #imagenes cuadradas
characters_to_generate = "ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz0123456789" # Caracteres del diccionario

# %% [markdown]
# ## Generacion del dataset de fuentes y palabras

# %%
#Descomprimo las fuentes

# !unzip {archivo_zip_fuentes} -d {carpeta_destino}
# Out:
# Archive:  /content/drive/MyDrive/tp_integrador/fuentes.zip
#   inflating: /content/fuentes/ocr_fonts_latin/Noto_Sans_Nag_Mundari/Noto_Sans_Nag_Mundari-700.ttf
#   inflating: /content/fuentes/ocr_fonts_latin/Noto_Sans_Mayan_Numerals/Noto_Sans_Mayan_Numerals-regular.ttf
#   inflating: /content/fuentes/ocr_fonts_latin/Noto_Sans_Oriya/Noto_Sans_Oriya-600.ttf
#   inflating: /content/fuentes/ocr_fonts_latin/Noto_Sans_NKo_Unjoined/Noto_Sans_NKo_Unjoined-regular.ttf
#   inflating: /content/fuentes/ocr_fonts_latin/Noto_Sans_Meetei_Mayek/Noto_Sans_Meetei_Mayek-800.ttf
#   inflating: /content/fuentes/ocr_fonts_latin/Noto_Sans_Meetei_Mayek/Noto_Sans_Meetei_Mayek-700.ttf
#   inflating: /content/fuentes/ocr_fonts_latin/Noto_Sans_Meetei_Mayek/Noto_Sans_Meetei_Mayek-500.ttf
#   inflating: /content/fuentes/ocr_fonts_latin/Noto_Sans_NKo_Unjoined/Noto_Sans_NKo_Unjoined-700.ttf
#   inflating: /content/fuentes/ocr_fonts_latin/Noto_Sans_Nag_Mundari/Noto_Sans_Nag_Mundari-regular.ttf
#   inflating: /content/fuentes/ocr_fonts_latin/Noto_Sans_Nag_Mundari/Noto_Sans_Nag_Mundari-500.ttf
#   inflating: /content/fuentes/ocr_fonts_latin/Noto_Sans_Old_Italic/Noto_Sans_Old_Italic-regular.ttf
#   inflating: /content/fuentes/ocr_fonts_latin/Noto_Sans_Meetei_Mayek/Noto_Sans_Meetei_Mayek-regular.ttf
#   inflating: /content/fuentes/ocr_fonts_latin/Noto_Sans_Nabataean/Noto_Sans_Nabataean-regular.ttf
#   inflating: /content/fuentes/ocr_fonts_latin/Noto_Sans_Old_North_Arabian/Noto_Sans_Old_North_Arabian-regular.ttf
#   inflating: /content/fuentes/ocr_fonts_latin/Noto_Sans_Old_Permic/Noto_Sans_Old_Permic-regular.ttf
#   inflating: /content/fuentes/ocr_fonts_latin/Noto_Sans_NKo_Unjoined/Noto_Sans_NKo_Unjoined-600.ttf
#   inflating: /content/fuentes/ocr_fonts_latin/Noto_Sans_Meetei_Mayek/Noto_Sans_Meetei_Mayek-300.ttf
#   inflating: /content/fuentes/ocr_fonts_latin/Noto_Sans_Oriya/Noto_Sans_Oriya-800.ttf
#   inflating: /content/fuentes/ocr_fonts_latin/Noto_Sans_Meetei_Mayek/Noto_Sans_Meetei_Mayek-900.ttf
#   inflating: /content/fuentes/ocr_fonts_latin/Noto_Sans_Oriya/Noto_Sans_Oriya-900.ttf
#   inflating: /content/fuentes/ocr_fonts_latin/Noto_Sans_Mongolian/Noto_Sans_Mongolian-regular.ttf
#   inflating: /content/fuentes/ocr_fonts_latin/Noto_Sans_Masaram_Gondi/Noto_Sans_Masaram_Gondi-regular.ttf
#   inflating: /content/fuentes/ocr_fonts_latin/Noto_Sans_Meroitic/Noto_Sans_Meroitic-regular.ttf
#   inflating: /content/fuentes/ocr_fonts_latin/fonts_dataset.csv
#   inflating: /content/fuentes/ocr_fonts_latin/Noto_Sans_Meetei_Mayek/Noto_Sans_Meetei_Mayek-200.ttf
#   inflating: /content/fuentes/ocr_fonts_latin/Noto_Sans_Multani/Noto_Sans_Multani-regular.ttf
#   inflating: /content/fuentes/ocr_fonts_latin/Noto_Sans_Linear_B/Noto_Sans_Linear_B-regular.ttf
#   inflating: /content/fuentes/ocr_fonts_latin/Noto_Sans_Meetei_Mayek/Noto_Sans_Meetei_Mayek-100.ttf
#   inflating: /content/fuentes/ocr_fonts_latin/Noto_Sans_NKo_Unjoined/Noto_Sans_NKo_Unjoined-500.ttf
#   inflating: /content/fuentes/ocr_fonts_latin/Noto_Sans_Oriya/Noto_Sans_Oriya-500.ttf
#   inflating: /content/fuentes/ocr_fonts_latin/Noto_Sans_Mahajani/Noto_Sans_Mahajani-regular.ttf
#   inflating: /content/fuentes/ocr_fonts_latin/Noto_Sans_Malayalam/Noto_Sans_Malayalam-900.ttf
#   inflating: /content/fuentes/ocr_fonts_latin/Noto_Sans_Oriya/Noto_Sans_Oriya-100.ttf
#   inflating: /content/fuentes/ocr_fonts_latin/Noto_Sans_Marchen/Noto_Sans_Marchen-regular.ttf
#   inflating: /content/fuentes/ocr_fonts_latin/Noto_Sans_
ttf
#   inflating: /content/fuentes/ocr_fonts_latin/Blinker/Blinker-200.ttf
#   inflating: /content/fuentes/ocr_fonts_latin/Blinker/Blinker-100.ttf
#   inflating: /content/fuentes/ocr_fonts_latin/Blinker/Blinker-700.ttf
#   inflating: /content/fuentes/ocr_fonts_latin/Blinker/Blinker-800.ttf
#   inflating: /content/fuentes/ocr_fonts_latin/Bai_Jamjuree/Bai_Jamjuree-italic.ttf
#   inflating: /content/fuentes/ocr_fonts_latin/Bai_Jamjuree/Bai_Jamjuree-500.ttf
#   inflating: /content/fuentes/ocr_fonts_latin/Bai_Jamjuree/Bai_Jamjuree-300italic.ttf
#   inflating: /content/fuentes/ocr_fonts_latin/Bai_Jamjuree/Bai_Jamjuree-700.ttf
#   inflating: /content/fuentes/ocr_fonts_latin/Blinker/Blinker-300.ttf
#   inflating: /content/fuentes/ocr_fonts_latin/Bai_Jamjuree/Bai_Jamjuree-600.ttf
#   inflating: /content/fuentes/ocr_fonts_latin/Bai_Jamjuree/Bai_Jamjuree-regular.ttf
#   inflating: /content/fuentes/ocr_fonts_latin/Bai_Jamjuree/Bai_Jamjuree-200.ttf
#   inflating: /content/fuentes/ocr_fonts_latin/Bellefair/Bellefair-regular.ttf
#   inflating: /content/fuentes/ocr_fonts_latin/Arima/Arima-700.ttf
#   inflating: /content/fuentes/ocr_fonts_latin/Alumni_Sans_Pinstripe/Alumni_Sans_Pinstripe-italic.ttf
#   inflating: /content/fuentes/ocr_fonts_latin/Anek_Latin/Anek_Latin-800.ttf
#   inflating: /content/fuentes/ocr_fonts_latin/Bai_Jamjuree/Bai_Jamjuree-500italic.ttf
#   inflating: /content/fuentes/ocr_fonts_latin/Arima/Arima-regular.ttf
#   inflating: /content/fuentes/ocr_fonts_latin/Bai_Jamjuree/Bai_Jamjuree-700italic.ttf
#   inflating: /content/fuentes/ocr_fonts_latin/Arima/Arima-300.ttf
#   inflating: /content/fuentes/ocr_fonts_latin/Bai_Jamjuree/Bai_Jamjuree-300.ttf
#   inflating: /content/fuentes/ocr_fonts_latin/Arima/Arima-500.ttf
#   inflating: /content/fuentes/ocr_fonts_latin/Babylonica/Babylonica-regular.ttf
#   inflating: /content/fuentes/ocr_fonts_latin/Bahiana/Bahiana-regular.ttf
#   inflating: /content/fuentes/ocr_fonts_latin/Blinker/Blinker-regular.ttf
#   inflating: /content/fuentes/ocr_fonts_latin/Barlow_Semi_Condensed/Barlow_Semi_Condensed-200italic.ttf
#   inflating: /content/fuentes/ocr_fonts_latin/Baloo_Bhai_2/Baloo_Bhai_2-700.ttf
#   inflating: /content/fuentes/ocr_fonts_latin/Bai_Jamjuree/Bai_Jamjuree-600italic.ttf
#   inflating: /content/fuentes/ocr_fonts_latin/Arima/Arima-600.ttf
#   inflating: /content/fuentes/ocr_fonts_latin/Arima/Arima-200.ttf
#   inflating: /content/fuentes/ocr_fonts_latin/Arima/Arima-100.ttf
#   inflating: /content/fuentes/ocr_fonts_latin/Bytesized/Bytesized-regular.ttf
#   inflating: /content/fuentes/ocr_fonts_latin/Anek_Latin/Anek_Latin-300.ttf
#   inflating: /content/fuentes/ocr_fonts_latin/ABeeZee/ABeeZee-regular.ttf
#   inflating: /content/fuentes/ocr_fonts_latin/Blinker/Blinker-600.ttf
#   inflating: /content/fuentes/ocr_fonts_latin/Buenard/Buenard-500.ttf
#   inflating: /content/fuentes/ocr_fonts_latin/Bai_Jamjuree/Bai_Jamjuree-200italic.ttf
#   inflating: /content/fuentes/ocr_fonts_latin/BIZ_UDMincho/BIZ_UDMincho-700.ttf
#   inflating: /content/fuentes/ocr_fonts_latin/BIZ_UDMincho/BIZ_UDMincho-regular.ttf

# %%
#Creo un dataset con las fuentes
def create_font_dataset(base_folder):
    """
    Crea un DataFrame de Pandas con información sobre las fuentes TTF encontradas.

    Args:
        base_folder (str): Ruta a la carpeta principal que contiene las subcarpetas de tipos de letra.

    Returns:
        pd.DataFrame: DataFrame con columnas 'font_name' y 'font_path'.
    """
    font_data = []
    print(f"Buscando archivos .ttf en: {base_folder}")
    for root, dirs, files in os.walk(base_folder):
        for file in files:
            # Comprobamos si el archivo termina con '.ttf' o '.otf' (sin importar mayúsculas/minúsculas)
            if file.lower().endswith(('.ttf', '.otf')):
                # Si es una fuente, añadimos la ruta completa a la lista
                full_font_path = os.path.join(root, file)
                full_font_path = full_font_path.replace('\\', '/').replace('//','/')
                font_file_name = file
                font_name = os.path.splitext(font_file_name)[0]
                font_data.append({
                    'font_name': font_name, # Usamos el nombre de la carpeta como nombre de la fuente
                    'font_path': full_font_path
                })

    return pd.DataFrame(font_data)

# %%
font_df = create_font_dataset(carpeta_destino)
font_df.info()
# Out:
# Buscando archivos .ttf en: /content/fuentes
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3919 entries, 0 to 3918
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   font_name  3919 non-null   object
#  1   font_path  3919 non-null   object
# dtypes: object(2)
# memory usage: 61.4+ KB

# %%
def generate_palabras(char_list_original, min_len=2, max_len=4):

    # 1. Convertir la cadena original a una lista y desordenarla una única vez
    shuffled_char_pool = list(char_list_original)
    random.shuffle(shuffled_char_pool)

    generated_combinations = []

    pool_index = 0
    total_pool_len = len(shuffled_char_pool)

    while pool_index < total_pool_len:
        # Calcular cuántos caracteres quedan en el pool
        remaining_chars = total_pool_len - pool_index

        # Determinar la longitud de la combinación actual
        # Si quedan 7 o menos caracteres (o menos de max_len) y al menos min_len, usa todos los restantes.
        # De lo contrario, elige una longitud aleatoria entre min_len y max_len.
        if remaining_chars <= max_len:
            current_len = remaining_chars
        else:
            current_len = random.randint(min_len, max_len)
            # Asegurarse de que la longitud elegida no exceda los caracteres restantes
            current_len = min(current_len, remaining_chars)

        # Extraer la combinación del pool
        combination_chars = shuffled_char_pool[pool_index : pool_index + current_len]
        combination = "".join(combination_chars)

        generated_combinations.append(combination)
        pool_index += current_len # Mover el índice al siguiente punto en el pool

    print(f"Número de palabras generadas: {len(generated_combinations)}")
    return generated_combinations

# %%
palabras_a_generar = []
if not font_df.empty:
    for index, font_row in font_df.iterrows():
        font_name = font_row['font_name']
        font_path = font_row['font_path']
        print(f"Generando caracteres para la fuente: {font_name} ({font_path})")
        for i in range(cantidad_de_repeticiones):
            lista_actual = generate_palabras(characters_to_generate, largo_minimo_palabra, largo_maximo_palabra)
            for palabra in lista_actual:
                palabras_a_generar.append({'palabra':palabra,'font_name':font_name,'font_path':font_path})

random.shuffle(palabras_a_generar)
palabras_a_generar = pd.DataFrame(palabras_a_generar)
print(f"Total de palabras a generar: {len(palabras_a_generar)}")
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# Número de palabras generadas: 25
# Generando caracteres para la fuente: Gabarito-800 (/content/fuentes/ocr_fonts_latin/Gabarito/Gabarito-800.ttf)
# Número de palabras generadas: 26
# Número de palabras generadas: 25
# Generando caracteres para la fuente: Gabarito-900 (/content/fuentes/ocr_fonts_latin/Gabarito/Gabarito-900.ttf)
# Número de palabras generadas: 27
# Número de palabras generadas: 28
# Generando caracteres para la fuente: Gabarito-600 (/content/fuentes/ocr_fonts_latin/Gabarito/Gabarito-600.ttf)
# Número de palabras generadas: 28
# Número de palabras generadas: 25
# Generando caracteres para la fuente: Gabarito-regular (/content/fuentes/ocr_fonts_latin/Gabarito/Gabarito-regular.ttf)
# Número de palabras generadas: 21
# Número de palabras generadas: 28
# Generando caracteres para la fuente: Gabarito-700 (/content/fuentes/ocr_fonts_latin/Gabarito/Gabarito-700.ttf)
# Número de palabras generadas: 30
# Número de palabras generadas: 24
# Generando caracteres para la fuente: Barlow_Semi_Condensed-500 (/content/fuentes/ocr_fonts_latin/Barlow_Semi_Condensed/Barlow_Semi_Condensed-500.ttf)
# Número de palabras generadas: 22
# Número de palabras generadas: 28
# Generando caracteres para la fuente: Barlow_Semi_Condensed-600 (/content/fuentes/ocr_fonts_latin/Barlow_Semi_Condensed/Barlow_Semi_Condensed-600.ttf)
# Número de palabras generadas: 20
# Número de palabras generadas: 27
# Generando caracteres para la fuente: Barlow_Semi_Condensed-700italic (/content/fuentes/ocr_fonts_latin/Barlow_Semi_Condensed/Barlow_Semi_Condensed-700italic.ttf)
# Número de palabras generadas: 25
# Número de palabras generadas: 24
# Generando caracteres para la fuente: Barlow_Semi_Condensed-300italic (/content/fuentes/ocr_fonts_latin/Barlow_Semi_Condensed/Barlow_Semi_Condensed-300italic.ttf)
# Número de palabras generadas: 26
# Número de palabras generadas: 29
# Generando caracteres para la fuente: Barlow_Semi_Condensed-300 (/content/fuentes/ocr_fonts_latin/Barlow_Semi_Condensed/Barlow_Semi_Condensed-300.ttf)
# Número de palabras generadas: 23
# Número de palabras generadas: 25
# Generando caracteres para la fuente: Barlow_Semi_Condensed-700 (/content/fuentes/ocr_fonts_latin/Barlow_Semi_Condensed/Barlow_Semi_Condensed-700.ttf)
# Número de palabras generadas: 26
# Número de palabras generadas: 26
# Generando caracteres para la fuente: Barlow_Semi_Condensed-900 (/content/fuentes/ocr_fonts_latin/Barlow_Semi_Condensed/Barlow_Semi_Condensed-900.ttf)
# Número de palabras generadas: 24
# Número de palabras generadas: 24
# Generando caracteres para la fuente: Barlow_Semi_Condensed-italic (/content/fuentes/ocr_fonts_latin/Barlow_Semi_Condensed/Barlow_Semi_Condensed-italic.ttf)
# Número de palabras generadas: 27
# Número de palabras generadas: 24
# Generando caracteres para la fuente: Barlow_Semi_Condensed-100italic (/content/fuentes/ocr_fonts_latin/Barlow_Semi_Condensed/Barlow_Semi_Condensed-100italic.ttf)
# Número de palabras generadas: 25
# Número de palabras generadas: 26
# Generando caracteres para la fuente: Barlow_Semi_Condensed-800 (/content/fuentes/ocr_fonts_latin/Barlow_Semi_Condensed/Barlow_Semi_Condensed-800.ttf)
# Número de palabras generadas: 24
# Número de palabras generadas: 28
# Generando caracteres para la fuente: Barlow_Semi_Condensed-regular (/content/fuentes/ocr_fonts_latin/Barlow_Semi_Condensed/Barlow_Semi_Condensed-regular.ttf)
# Número de palabras generadas: 26
# Número de palabras generadas: 25
# Generando caracteres para la fuente: Barlow_Semi_Condensed-200italic (/content/fuentes/ocr_fonts_latin/Barlow_Semi_Condensed/Barlow_Semi_Condensed-200italic.ttf)
# Número de palabras generadas: 25
# Número de palabras generadas: 22
# Generando caracteres para la fuente: Barlow_Semi_Condensed-800italic (/content/fuentes/ocr_fonts_latin/Barlow_Semi_Condensed/Barlow_Semi_Condensed-800italic.ttf)
# Número de palabras generadas: 23
# Número de palabras generadas: 26
# Generando caracteres para la fuente: Barlow_Semi_Condensed-200 (/content/fuentes/ocr_fonts_latin/Barlow_Semi_Condensed/Barlow_Semi_Condensed-200.ttf)
# Número de palabras generadas: 26
# Número de palabras generadas: 23
# Generando caracteres para la fuente: Barlow_Semi_Condensed-600italic (/content/fuentes/ocr_fonts_latin/Barlow_Semi_Condensed/Barlow_Semi_Condensed-600italic.ttf)
# Número de palabras generadas: 21
# Número de palabras generadas: 23
# Generando caracteres para la fuente: Barlow_Semi_Condensed-900italic (/content/fuentes/ocr_fonts_latin/Barlow_Semi_Condensed/Barlow_Semi_Condensed-900italic.ttf)
# Número de palabras generadas: 25
# Número de palabras generadas: 24
# Generando caracteres para la fuente: Barlow_Semi_Condensed-100 (/content/fuentes/ocr_fonts_latin/Barlow_Semi_Condensed/Barlow_Semi_Condensed-100.ttf)
# Número de palabras generadas: 21
# Número de palabras generadas: 23
# Generando caracteres para la fuente: Barlow_Semi_Condensed-500italic (/content/fuentes/ocr_fonts_latin/Barlow_Semi_Condensed/Barlow_Semi_Condensed-500italic.ttf)
# Número de palabras generadas: 23
# Número de palabras generadas: 27
# Generando caracteres para la fuente: Bona_Nova_SC-regular (/content/fuentes/ocr_fonts_latin/Bona_Nova_SC/Bona_Nova_SC-regular.ttf)
# Número de palabras generadas: 27
# Número de palabras generadas: 21
# Generando caracteres para la fuente: Bona_Nova_SC-italic (/content/fuentes/ocr_fonts_latin/Bona_Nova_SC/Bona_Nova_SC-italic.ttf)
# Número de palabras generadas: 25
# Número de palabras generadas: 24
# Generando caracteres para la fuente: Bona_Nova_SC-700 (/content/fuentes/ocr_fonts_latin/Bona_Nova_SC/Bona_Nova_SC-700.ttf)
# Número de palabras generadas: 25
# Número de palabras generadas: 26
# Generando caracteres para la fuente: Molle-italic (/content/fuentes/ocr_fonts_latin/Molle/Molle-italic.ttf)
# Número de palabras generadas: 23
# Número de palabras generadas: 26
# Generando caracteres para la fuente: Micro_5_Charted-regular (/content/fuentes/ocr_fonts_latin/Micro_5_Charted/Micro_5_Charted-regular.ttf)
# Número de palabras generadas: 23
# Número de palabras generadas: 25
# Generando caracteres para la fuente: Ingrid_Darling-regular (/content/fuentes/ocr_fonts_latin/Ingrid_Darling/Ingrid_Darling-regular.ttf)
# Número de palabras generadas: 23
# Número de palabras generadas: 26
# Generando caracteres para la fuente: Bubbler_One-regular (/content/fuentes/ocr_fonts_latin/Bubbler_One/Bubbler_One-regular.ttf)
# Número de palabras generadas: 23
# Número de palabras generadas: 22
# Generando caracteres para la fuente: Faster_One-regular (/content/fuentes/ocr_fonts_latin/Faster_One/Faster_One-regular.ttf)
# Número de palabras generadas: 22
# Número de palabras generadas: 26
# Generando caracteres para la fuente: Micro_5-regular (/content/fuentes/ocr_fonts_latin/Micro_5/Micro_5-regular.ttf)
# Número de palabras generadas: 25
# Número de palabras generadas: 21
# Generando caracteres para la fuente: Castoro_Titling-regular (/content/fuentes/ocr_fonts_latin/Castoro_Titling/Castoro_Titling-regular.ttf)
# Número de palabras generadas: 27
# Número de palabras generadas: 25
# Generando caracteres para la fuente: Alice-regular (/content/fuentes/ocr_fonts_latin/Alice/Alice-regular.ttf)
# Número de palabras generadas: 23
# Número de palabras generadas: 27
# Generando caracteres para la fuente: Marcellus-regular (/content/fuentes/ocr_fonts_latin/Marcellus/Marcellus-regular.ttf)
# Número de palabras generadas: 23
# Número de palabras generadas: 20
# Generando caracteres para la fuente: Alegreya-700 (/content/fuentes/ocr_fonts_latin/Alegreya/Alegreya-700.ttf)
# Número de palabras generadas: 25
# Número de palabras generadas: 27
# Generando caracteres para la fuente: Alegreya-regular (/content/fuentes/ocr_fonts_latin/Alegreya/Alegreya-regular.ttf)
# Número de palabras generadas: 25
# Número de palabras generadas: 29
# Generando caracteres para la fuente: Alegreya-600 (/content/fuentes/ocr_fonts_latin/Alegreya/Alegreya-600.ttf)
# Número de palabras generadas: 21
# Número de palabras generadas: 26
# Generando caracteres para la fuente: Alegreya-800italic (/content/fuentes/ocr_fonts_latin/Alegreya/Alegreya-800italic.ttf)
# Número de palabras generadas: 23
# Número de palabras generadas: 25
# Generando caracteres para la fuente: Alegreya-italic (/content/fuentes/ocr_fonts_latin/Alegreya/Alegreya-italic.ttf)
# Número de palabras generadas: 22
# Número de palabras generadas: 21
# Generando caracteres para la fuente: Alegreya-900italic (/content/fuentes/ocr_fonts_latin/Alegreya/Alegreya-900italic.ttf)
# Número de palabras generadas: 21
# Número de palabras generadas: 23
# Generando caracteres para la fuente: Alegreya-900 (/content/fuentes/ocr_fonts_latin/Alegreya/Alegreya-900.ttf)
# Número de palabras generadas: 22
# Número de palabras generadas: 27
# Generando caracteres para la fuente: Alegreya-700italic (/content/fuentes/ocr_fonts_latin/Alegreya/Alegreya-700italic.ttf)
# Número de palabras generadas: 23
# Número de palabras generadas: 26
# Generando caracteres para la fuente: Alegreya-800 (/content/fuentes/ocr_fonts_latin/Alegreya/Alegreya-800.ttf)
# Número de palabras generadas: 24
# Número de palabras generadas: 21
# Generando caracteres para la fuente: Alegreya-600italic (/content/fuentes/ocr_fonts_latin/Alegreya/Alegreya-600italic.ttf)
# Número de palabras generadas: 27
# Número de palabras generadas: 25
# Generando caracteres para la fuente: Alegreya-500 (/content/fuentes/ocr_fonts_latin/Alegreya/Alegreya-500.ttf)
# Número de palabras generadas: 23
# Número de palabras generadas: 26
# Generando caracteres para la fuente: Alegreya-500italic (/content/fuentes/ocr_fonts_latin/Alegreya/Alegreya-500italic.ttf)
# Número de palabras generadas: 22
# Número de palabras generadas: 25
# Generando caracteres para la fuente: Archivo_Narrow-500italic (/content/fuentes/ocr_fonts_latin/Archivo_Narrow/Archivo_Narrow-500italic.ttf)
# Número de palabras generadas: 28
# Número de palabras generadas: 24
# Generando caracteres para la fuente: Archivo_Narrow-700 (/content/fuentes/ocr_fonts_latin/Archivo_Narrow/Archivo_Narrow-700.ttf)
# Número de palabras generadas: 22
# Número de palabras generadas: 24
# Generando caracteres para la fuente: Archivo_Narrow-700italic (/content/fuentes/ocr_fonts_latin/Archivo_Narrow/Archivo_Narrow-700italic.ttf)
# Número de palabras generadas: 20
# Número de palabras generadas: 24
# Generando caracteres para la fuente: Archivo_Narrow-600italic (/content/fuentes/ocr_fonts_latin/Archivo_Narrow/Archivo_Narrow-600italic.ttf)
# Número de palabras generadas: 26
# Número de palabras generadas: 26
# Generando caracteres para la fuente: Archivo_Narrow-500 (/content/fuentes/ocr_fonts_latin/Archivo_Narrow/Archivo_Narrow-500.ttf)
# Número de palabras generadas: 24
# Número de palabras generadas: 28
# Generando caracteres para la fuente: Archivo_Narrow-regular (/content/fuentes/ocr_fonts_latin/Archivo_Narrow/Archivo_Narrow-regular.ttf)
# Número de palabras generadas: 21
# Número de palabras generadas: 28
# Generando caracteres para la fuente: Archivo_Narrow-600 (/content/fuentes/ocr_fonts_latin/Archivo_Narrow/Archivo_Narrow-600.ttf)
# Número de palabras generadas: 22
# Número de palabras generadas: 22
# Generando caracteres para la fuente: Archivo_Narrow-italic (/content/fuentes/ocr_fonts_latin/Archivo_Narrow/Archivo_Narrow-italic.ttf)
# Número de palabras generadas: 25
# Número de palabras generadas: 25
# Generando caracteres para la fuente: Istok_Web-700 (/content/fuentes/ocr_fonts_latin/Istok_Web/Istok_Web-700.ttf)
# Número de palabras generadas: 28
# Número de palabras generadas: 26
# Generando caracteres para la fuente: Istok_Web-regular (/content/fuentes/ocr_fonts_latin/Istok_Web/Istok_Web-regular.ttf)
# Número de palabras generadas: 23
# Número de palabras generadas: 27
# Generando caracteres para la fuente: Istok_Web-italic (/content/fuentes/ocr_fonts_latin/Istok_Web/Istok_Web-italic.ttf)
# Número de palabras generadas: 25
# Número de palabras generadas: 21
# Generando caracteres para la fuente: Istok_Web-700italic (/content/fuentes/ocr_fonts_latin/Istok_Web/Istok_Web-700italic.ttf)
# Número de palabras generadas: 25
# Número de palabras generadas: 25
# Generando caracteres para la fuente: Agbalumo-regular (/content/fuentes/ocr_fonts_latin/Agbalumo/Agbalumo-regular.ttf)
# Número de palabras generadas: 25
# Número de palabras generadas: 24
# Generando caracteres para la fuente: Reddit_Mono-regular (/content/fuentes/ocr_fonts_latin/Reddit_Mono/Reddit_Mono-regular.ttf)
# Número de palabras generadas: 25
# Número de palabras generadas: 23
# Generando caracteres para la fuente: Reddit_Mono-500 (/content/fuentes/ocr_fonts_latin/Reddit_Mono/Reddit_Mono-500.ttf)
# Número de palabras generadas: 26
# Número de palabras generadas: 25
# Generando caracteres para la fuente: Reddit_Mono-800 (/content/fuentes/ocr_fonts_latin/Reddit_Mono/Reddit_Mono-800.ttf)
# Número de palabras generadas: 25
# Número de palabras generadas: 28
# Generando caracteres para la fuente: Reddit_Mono-700 (/content/fuentes/ocr_fonts_latin/Reddit_Mono/Reddit_Mono-700.ttf)
# Número de palabras generadas: 24
# Número de palabras generadas: 28
# Generando caracteres para la fuente: Reddit_Mono-900 (/content/fuentes/ocr_fonts_latin/Reddit_Mono/Reddit_Mono-900.ttf)
# Número de palabras generadas: 25
# Número de palabras generadas: 25
# Generando caracteres para la fuente: Reddit_Mono-300 (/content/fuentes/ocr_fonts_latin/Reddit_Mono/Reddit_Mono-300.ttf)
# Número de palabras generadas: 25
# Número de palabras generadas: 25
# Generando caracteres para la fuente: Reddit_Mono-200 (/content/fuentes/ocr_fonts_latin/Reddit_Mono/Reddit_Mono-200.ttf)
# Número de palabras generadas: 22
# Número de palabras generadas: 26
# Generando caracteres para la fuente: Reddit_Mono-600 (/content/fuentes/ocr_fonts_latin/Reddit_Mono/Reddit_Mono-600.ttf)
# Número de palabras generadas: 28
# Número de palabras generadas: 29
# Generando caracteres para la fuente: Dynalight-regular (/content/fuentes/ocr_fonts_latin/Dynalight/Dynalight-regular.ttf)
# Número de palabras generadas: 25
# Número de palabras generadas: 23
# Generando caracteres para la fuente: Cal_Sans-regular (/content/fuentes/ocr_fonts_latin/Cal_Sans/Cal_Sans-regular.ttf)
# Número de palabras generadas: 27
# Número de palabras generadas: 25
# Generando caracteres para la fuente: Hanalei_Fill-regular (/content/fuentes/ocr_fonts_latin/Hanalei_Fill/Hanalei_Fill-regular.ttf)
# Número de palabras generadas: 24
# Número de palabras generadas: 25
# Generando caracteres para la fuente: Epilogue-200italic (/content/fuentes/ocr_fonts_latin/Epilogue/Epilogue-200italic.ttf)
# Número de palabras generadas: 26
# Número de palabras generadas: 23
# Generando caracteres para la fuente: Epilogue-800 (/content/fuentes/ocr_fonts_latin/Epilogue/Epilogue-800.ttf)
# Número de palabras generadas: 24
# Número de palabras generadas: 22
# Generando caracteres para la fuente: Epilogue-100italic (/content/fuentes/ocr_fonts_latin/Epilogue/Epilogue-100italic.ttf)
# Número de palabras generadas: 22
# Número de palabras generadas: 25
# Generando caracteres para la fuente: Epilogue-300 (/content/fuentes/ocr_fonts_latin/Epilogue/Epilogue-300.ttf)
# Número de palabras generadas: 24
# Número de palabras generadas: 28
# Generando caracteres para la fuente: Epilogue-300italic (/content/fuentes/ocr_fonts_latin/Epilogue/Epilogue-300italic.ttf)
# Número de palabras generadas: 24
# Número de palabras generadas: 27
# Generando caracteres para la fuente: Epilogue-500italic (/content/fuentes/ocr_fonts_latin/Epilogue/Epilogue-500italic.ttf)
# Número de palabras generadas: 27
# Número de palabras generadas: 25
# Generando caracteres para la fuente: Epilogue-200 (/content/fuentes/ocr_fonts_latin/Epilogue/Epilogue-200.ttf)
# Número de palabras generadas: 23
# Número de palabras generadas: 26
# Generando caracteres para la fuente: Epilogue-800italic (/content/fuentes/ocr_fonts_latin/Epilogue/Epilogue-800italic.ttf)
# Número de palabras generadas: 22
# Número de palabras generadas: 26
# Generando caracteres para la fuente: Epilogue-700italic (/content/fuentes/ocr_fonts_latin/Epilogue/Epilogue-700italic.ttf)
# Número de palabras generadas: 25
# Número de palabras generadas: 23
# Generando caracteres para la fuente: Epilogue-regular (/content/fuentes/ocr_fonts_latin/Epilogue/Epilogue-regular.ttf)
# Número de palabras generadas: 25
# Número de palabras generadas: 28
# Generando caracteres para la fuente: Epilogue-900 (/content/fuentes/ocr_fonts_latin/Epilogue/Epilogue-900.ttf)
# Número de palabras generadas: 26
# Número de palabras generadas: 24
# Generando caracteres para la fuente: Epilogue-900italic (/content/fuentes/ocr_fonts_latin/Epilogue/Epilogue-900italic.ttf)
# Número de palabras generadas: 22
# Número de palabras generadas: 27
# Generando caracteres para la fuente: Epilogue-600 (/content/fuentes/ocr_fonts_latin/Epilogue/Epilogue-600.ttf)
# Número de palabras generadas: 26
# Número de palabras generadas: 20
# Generando caracteres para la fuente: Epilogue-600italic (/content/fuentes/ocr_fonts_latin/Epilogue/Epilogue-600italic.ttf)
# Número de palabras generadas: 28
# Número de palabras generadas: 22
# Generando caracteres para la fuente: Epilogue-100 (/content/fuentes/ocr_fonts_latin/Epilogue/Epilogue-100.ttf)
# Número de palabras generadas: 22
# Número de palabras generadas: 25
# Generando caracteres para la fuente: Epilogue-italic (/content/fuentes/ocr_fonts_latin/Epilogue/Epilogue-italic.ttf)
# Número de palabras generadas: 25
# Número de palabras generadas: 24
# Generando caracteres para la fuente: Epilogue-500 (/content/fuentes/ocr_fonts_latin/Epilogue/Epilogue-500.ttf)
# Número de palabras generadas: 26
# Número de palabras generadas: 25
# Generando caracteres para la fuente: Merriweather_Sans-italic (/content/fuentes/ocr_fonts_latin/Merriweather_Sans/Merriweather_Sans-italic.ttf)
# Número de palabras generadas: 25
# Número de palabras generadas: 24
# Generando caracteres para la fuente: Merriweather_Sans-500 (/content/fuentes/ocr_fonts_latin/Merriweather_Sans/Merriweather_Sans-500.ttf)
# Número de palabras generadas: 22
# Número de palabras generadas: 25
# Generando caracteres para la fuente: Merriweather_Sans-300 (/content/fuentes/ocr_fonts_latin/Merriweather_Sans/Merriweather_Sans-300.ttf)
# Número de palabras generadas: 23
# Número de palabras generadas: 23
# Generando caracteres para la fuente: Merriweather_Sans-800 (/content/fuentes/ocr_fonts_latin/Merriweather_Sans/Merriweather_Sans-800.ttf)
# Número de palabras generadas: 24
# Número de palabras generadas: 26
# Generando caracteres para la fuente: Merriweather_Sans-600 (/content/fuentes/ocr_fonts_latin/Merriweather_Sans/Merriweather_Sans-600.ttf)
# Número de palabras generadas: 21
# Número de palabras generadas: 27
# Generando caracteres para la fuente: Merriweather_Sans-regular (/content/fuentes/ocr_fonts_latin/Merriweather_Sans/Merriweather_Sans-regular.ttf)
# Número de palabras generadas: 23
# Número de palabras generadas: 26
# Generando caracteres para la fuente: Merriweather_Sans-600italic (/content/fuentes/ocr_fonts_latin/Merriweather_Sans/Merriweather_Sans-600italic.ttf)
# Número de palabras generadas: 22
# Número de palabras generadas: 25
# Generando caracteres para la fuente: Merriweather_Sans-700italic (/content/fuentes/ocr_fonts_latin/Merriweather_Sans/Merriweather_Sans-700italic.ttf)
# Número de palabras generadas: 25
# Número de palabras generadas: 25
# Generando caracteres para la fuente: Merriweather_Sans-500italic (/content/fuentes/ocr_fonts_latin/Merriweather_Sans/Merriweather_Sans-500italic.ttf)
# Número de palabras generadas: 24
# Número de palabras generadas: 26
# Generando caracteres para la fuente: Merriweather_Sans-300italic (/content/fuentes/ocr_fonts_latin/Merriweather_Sans/Merriweather_Sans-300italic.ttf)
# Número de palabras generadas: 26
# Número de palabras generadas: 26
# Generando caracteres para la fuente: Merriweather_Sans-700 (/content/fuentes/ocr_fonts_latin/Merriweather_Sans/Merriweather_Sans-700.ttf)
# Número de palabras generadas: 25
# Número de palabras generadas: 23
# Generando caracteres para la fuente: Merriweather_Sans-800italic (/content/fuentes/ocr_fonts_latin/Merriweather_Sans/Merriweather_Sans-800italic.ttf)
# Número de palabras generadas: 27
# Número de palabras generadas: 26
# Generando caracteres para la fuente: Corben-700 (/content/fuentes/ocr_fonts_latin/Corben/Corben-700.ttf)
# Número de palabras generadas: 24
# Número de palabras generadas: 24
# Generando caracteres para la fuente: Corben-regular (/content/fuentes/ocr_fonts_latin/Corben/Corben-regular.ttf)
# Número de palabras generadas: 23
# Número de palabras generadas: 23
# Generando caracteres para la fuente: Engagement-regular (/content/fuentes/ocr_fonts_latin/Engagement/Engagement-regular.ttf)
# Número de palabras generadas: 24
# Número de palabras generadas: 25
# Generando caracteres para la fuente: Monsieur_La_Doulaise-regular (/content/fuentes/ocr_fonts_latin/Monsieur_La_Doulaise/Monsieur_La_Doulaise-regular.ttf)
# Número de palabras generadas: 27
# Número de palabras generadas: 27
# Generando caracteres para la fuente: Grechen_Fuemen-regular (/content/fuentes/ocr_fonts_latin/Grechen_Fuemen/Grechen_Fuemen-regular.ttf)
# Número de palabras generadas: 23
# Número de palabras generadas: 23
# Generando caracteres para la fuente: Geist-regular (/content/fuentes/ocr_fonts_latin/Geist/Geist-regular.ttf)
# Número de palabras generadas: 21
# Número de palabras generadas: 21
# Generando caracteres para la fuente: Geist-100 (/content/fuentes/ocr_fonts_latin/Geist/Geist-100.ttf)
# Número de palabras generadas: 25
# Número de palabras generadas: 23
# Generando caracteres para la fuente: Geist-800 (/content/fuentes/ocr_fonts_latin/Geist/Geist-800.ttf)
# Número de palabras generadas: 22
# Número de palabras generadas: 23
# Generando caracteres para la fuente: Geist-700 (/content/fuentes/ocr_fonts_latin/Geist/Geist-700.ttf)
# Número de palabras generadas: 25
# Número de palabras generadas: 27
# Generando caracteres para la fuente: Geist-500 (/content/fuentes/ocr_fonts_latin/Geist/Geist-500.ttf)
# Número de palabras generadas: 26
# Número de palabras generadas: 28
# Generando caracteres para la fuente: Geist-900 (/content/fuentes/ocr_fonts_latin/Geist/Geist-900.ttf)
# Número de palabras generadas: 25
# Número de palabras generadas: 21
# Generando caracteres para la fuente: Geist-300 (/content/fuentes/ocr_fonts_latin/Geist/Geist-300.ttf)
# Número de palabras generadas: 26
# Número de palabras generadas: 27
# Generando caracteres para la fuente: Geist-600 (/content/fuentes/ocr_fonts_latin/Geist/Geist-600.ttf)
# Número de palabras generadas: 24
# Número de palabras generadas: 32
# Generando caracteres para la fuente: Geist-200 (/content/fuentes/ocr_fonts_latin/Geist/Geist-200.ttf)
# Número de palabras generadas: 28
# Número de palabras generadas: 25
# Generando caracteres para la fuente: Edu_SA_Hand-regular (/content/fuentes/ocr_fonts_latin/Edu_SA_Hand/Edu_SA_Hand-regular.ttf)
# Número de palabras generadas: 24
# Número de palabras generadas: 24
# Generando caracteres para la fuente: Edu_SA_Hand-500 (/content/fuentes/ocr_fonts_latin/Edu_SA_Hand/Edu_SA_Hand-500.ttf)
# Número de palabras generadas: 24
# Número de palabras generadas: 27
# Generando caracteres para la fuente: Edu_SA_Hand-600 (/content/fuentes/ocr_fonts_latin/Edu_SA_Hand/Edu_SA_Hand-600.ttf)
# Número de palabras generadas: 26
# Número de palabras generadas: 25
# Generando caracteres para la fuente: Edu_SA_Hand-700 (/content/fuentes/ocr_fonts_latin/Edu_SA_Hand/Edu_SA_Hand-700.ttf)
# Número de palabras generadas: 25
# Número de palabras generadas: 23
# Generando caracteres para la fuente: Castoro-regular (/content/fuentes/ocr_fonts_latin/Castoro/Castoro-regular.ttf)
# Número de palabras generadas: 24
# Número de palabras generadas: 22
# Generando caracteres para la fuente: Castoro-italic (/content/fuentes/ocr_fonts_latin/Castoro/Castoro-italic.ttf)
# Número de palabras generadas: 23
# Número de palabras generadas: 28
# Generando caracteres para la fuente: Karla-300 (/content/fuentes/ocr_fonts_latin/Karla/Karla-300.ttf)
# Número de palabras generadas: 25
# Número de palabras generadas: 25
# Generando caracteres para la fuente: Karla-700 (/content/fuentes/ocr_fonts_latin/Karla/Karla-700.ttf)
# Número de palabras generadas: 26
# Número de palabras generadas: 23
# Generando caracteres para la fuente: Karla-600italic (/content/fuentes/ocr_fonts_latin/Karla/Karla-600italic.ttf)
# Número de palabras generadas: 25
# Número de palabras generadas: 23
# Generando caracteres para la fuente: Karla-700italic (/content/fuentes/ocr_fonts_latin/Karla/Karla-700italic.ttf)
# Número de palabras generadas: 24
# Número de palabras generadas: 25
# Generando caracteres para la fuente: Karla-800 (/content/fuentes/ocr_fonts_latin/Karla/Karla-800.ttf)
# Número de palabras generadas: 23
# Número de palabras generadas: 25
# Generando caracteres para la fuente: Karla-500italic (/content/fuentes/ocr_fonts_latin/Karla/Karla-500italic.ttf)
# Número de palabras generadas: 26
# Número de palabras generadas: 26
# Generando caracteres para la fuente: Karla-800italic (/content/fuentes/ocr_fonts_latin/Karla/Karla-800italic.ttf)
# Número de palabras generadas: 25
# Número de palabras generadas: 27
# Generando caracteres para la fuente: Karla-200italic (/content/fuentes/ocr_fonts_latin/Karla/Karla-200italic.ttf)
# Número de palabras generadas: 22
# Número de palabras generadas: 24
# Generando caracteres para la fuente: Karla-300italic (/content/fuentes/ocr_fonts_latin/Karla/Karla-300italic.ttf)
# Número de palabras generadas: 25
# Número de palabras generadas: 25
# Generando caracteres para la fuente: Karla-regular (/content/fuentes/ocr_fonts_latin/Karla/Karla-regular.ttf)
# Número de palabras generadas: 22
# Número de palabras generadas: 26
# Generando caracteres para la fuente: Karla-600 (/content/fuentes/ocr_fonts_latin/Karla/Karla-600.ttf)
# Número de palabras generadas: 24
# Número de palabras generadas: 25
# Generando caracteres para la fuente: Karla-200 (/content/fuentes/ocr_fonts_latin/Karla/Karla-200.ttf)
# Número de palabras generadas: 24
# Número de palabras generadas: 24
# Generando caracteres para la fuente: Karla-italic (/content/fuentes/ocr_fonts_latin/Karla/Karla-italic.ttf)
# Número de palabras generadas: 25
# Número de palabras generadas: 25
# Generando caracteres para la fuente: Karla-500 (/content/fuentes/ocr_fonts_latin/Karla/Karla-500.ttf)
# Número de palabras generadas: 27
# Número de palabras generadas: 24
# Generando caracteres para la fuente: Kite_One-regular (/content/fuentes/ocr_fonts_latin/Kite_One/Kite_One-regular.ttf)
# Número de palabras generadas: 26
# Número de palabras generadas: 26
# Generando caracteres para la fuente: Maven_Pro-700 (/content/fuentes/ocr_fonts_latin/Maven_Pro/Maven_Pro-700.ttf)
# Número de palabras generadas: 26
# Número de palabras generadas: 22
# Generando caracteres para la fuente: Maven_Pro-regular (/content/fuentes/ocr_fonts_latin/Maven_Pro/Maven_Pro-regular.ttf)
# Número de palabras generadas: 28
# Número de palabras generadas: 23
# Generando caracteres para la fuente: Maven_Pro-600 (/content/fuentes/ocr_fonts_latin/Maven_Pro/Maven_Pro-600.ttf)
# Número de palabras generadas: 27
# Número de palabras generadas: 22
# Generando caracteres para la fuente: Maven_Pro-900 (/content/fuentes/ocr_fonts_latin/Maven_Pro/Maven_Pro-900.ttf)
# Número de palabras generadas: 23
# Número de palabras generadas: 24
# Generando caracteres para la fuente: Maven_Pro-500 (/content/fuentes/ocr_fonts_latin/Maven_Pro/Maven_Pro-500.ttf)
# Número de palabras generadas: 25
# Número de palabras generadas: 28
# Generando caracteres para la fuente: Maven_Pro-800 (/content/fuentes/ocr_fonts_latin/Maven_Pro/Maven_Pro-800.ttf)
# Número de palabras generadas: 27
# Número de palabras generadas: 23
# Generando caracteres para la fuente: BIZ_UDPMincho-regular (/content/fuentes/ocr_fonts_latin/BIZ_UDPMincho/BIZ_UDPMincho-regular.ttf)
# Número de palabras generadas: 26
# Número de palabras generadas: 23
# Generando caracteres para la fuente: BIZ_UDPMincho-700 (/content/fuentes/ocr_fonts_latin/BIZ_UDPMincho/BIZ_UDPMincho-700.ttf)
# Número de palabras generadas: 22
# Número de palabras generadas: 25
# Generando caracteres para la fuente: Noto_Sans_HK-900 (/content/fuentes/ocr_fonts_latin/Noto_Sans_HK/Noto_Sans_HK-900.ttf)
# Número de palabras generadas: 26
# Número de palabras generadas: 26
# Generando caracteres para la fuente: Noto_Sans_HK-700 (/content/fuentes/ocr_fonts_latin/Noto_Sans_HK/Noto_Sans_HK-700.ttf)
# Número de palabras generadas: 22
# Número de palabras generadas: 21
# Generando caracteres para la fuente: Noto_Sans_HK-600 (/content/fuentes/ocr_fonts_latin/Noto_Sans_HK/Noto_Sans_HK-600.ttf)
# Número de palabras generadas: 28
# Número de palabras generadas: 27
# Generando caracteres para la fuente: Noto_Sans_HK-regular (/content/fuentes/ocr_fonts_latin/Noto_Sans_HK/Noto_Sans_HK-regular.ttf)
# Número de palabras generadas: 24
# Número de palabras generadas: 27
# Generando caracteres para la fuente: Noto_Sans_HK-800 (/content/fuentes/ocr_fonts_latin/Noto_Sans_HK/Noto_Sans_HK-800.ttf)
# Número de palabras generadas: 27
# Número de palabras generadas: 24
# Generando caracteres para la fuente: Noto_Sans_HK-100 (/content/fuentes/ocr_fonts_latin/Noto_Sans_HK/Noto_Sans_HK-100.ttf)
# Número de palabras generadas: 28
# Número de palabras generadas: 23
# Generando caracteres para la fuente: Noto_Sans_HK-500 (/content/fuentes/ocr_fonts_latin/Noto_Sans_HK/Noto_Sans_HK-500.ttf)
# Número de palabras generadas: 21
# Número de palabras generadas: 25
# Generando caracteres para la fuente: Noto_Sans_HK-300 (/content/fuentes/ocr_fonts_latin/Noto_Sans_HK/Noto_Sans_HK-300.ttf)
# Número de palabras generadas: 24
# Número de palabras generadas: 30
# Generando caracteres para la fuente: Noto_Sans_HK-200 (/content/fuentes/ocr_fonts_latin/Noto_Sans_HK/Noto_Sans_HK-200.ttf)
# Número de palabras generadas: 29
# Número de palabras generadas: 26
# Generando caracteres para la fuente: Cherry_Swash-700 (/content/fuentes/ocr_fonts_latin/Cherry_Swash/Cherry_Swash-700.ttf)
# Número de palabras generadas: 25
# Número de palabras generadas: 24
# Generando caracteres para la fuente: Cherry_Swash-regular (/content/fuentes/ocr_fonts_latin/Cherry_Swash/Cherry_Swash-regular.ttf)
# Número de palabras generadas: 24
# Número de palabras generadas: 25
# Generando caracteres para la fuente: Bytesized-regular (/content/fuentes/ocr_fonts_latin/Bytesized/Bytesized-regular.ttf)
# Número de palabras generadas: 24
# Número de palabras generadas: 25
# Generando caracteres para la fuente: Kodchasan-300italic (/content/fuentes/ocr_fonts_latin/Kodchasan/Kodchasan-300italic.ttf)
# Número de palabras generadas: 25
# Número de palabras generadas: 23
# Generando caracteres para la fuente: Kodchasan-700italic (/content/fuentes/ocr_fonts_latin/Kodchasan/Kodchasan-700italic.ttf)
# Número de palabras generadas: 25
# Número de palabras generadas: 22
# Generando caracteres para la fuente: Kodchasan-500 (/content/fuentes/ocr_fonts_latin/Kodchasan/Kodchasan-500.ttf)
# Número de palabras generadas: 24
# Número de palabras generadas: 22
# Generando caracteres para la fuente: Kodchasan-300 (/content/fuentes/ocr_fonts_latin/Kodchasan/Kodchasan-300.ttf)
# Número de palabras generadas: 28
# Número de palabras generadas: 25
# Generando caracteres para la fuente: Kodchasan-200 (/content/fuentes/ocr_fonts_latin/Kodchasan/Kodchasan-200.ttf)
# Número de palabras generadas: 25
# Número de palabras generadas: 27
# Generando caracteres para la fuente: Kodchasan-italic (/content/fuentes/ocr_fonts_latin/Kodchasan/Kodchasan-italic.ttf)
# Número de palabras generadas: 27
# Número de palabras generadas: 28
# Generando caracteres para la fuente: Kodchasan-500italic (/content/fuentes/ocr_fonts_latin/Kodchasan/Kodchasan-500italic.ttf)
# Número de palabras generadas: 27
# Número de palabras generadas: 25
# Generando caracteres para la fuente: Kodchasan-700 (/content/fuentes/ocr_fonts_latin/Kodchasan/Kodchasan-700.ttf)
# Número de palabras generadas: 28
# Número de palabras generadas: 21
# Generando caracteres para la fuente: Kodchasan-600italic (/content/fuentes/ocr_fonts_latin/Kodchasan/Kodchasan-600italic.ttf)
# Número de palabras generadas: 26
# Número de palabras generadas: 25
# Generando caracteres para la fuente: Kodchasan-regular (/content/fuentes/ocr_fonts_latin/Kodchasan/Kodchasan-regular.ttf)
# Número de palabras generadas: 26
# Número de palabras generadas: 23
# Generando caracteres para la fuente: Kodchasan-200italic (/content/fuentes/ocr_fonts_latin/Kodchasan/Kodchasan-200italic.ttf)
# Número de palabras generadas: 27
# Número de palabras generadas: 23
# Generando caracteres para la fuente: Kodchasan-600 (/content/fuentes/ocr_fonts_latin/Kodchasan/Kodchasan-600.ttf)
# Número de palabras generadas: 24
# Número de palabras generadas: 26
# Generando caracteres para la fuente: Bungee-regular (/content/fuentes/ocr_fonts_latin/Bungee/Bungee-regular.ttf)
# Número de palabras generadas: 23
# Número de palabras generadas: 25
# Generando caracteres para la fuente: Chilanka-regular (/content/fuentes/ocr_fonts_latin/Chilanka/Chilanka-regular.ttf)
# Número de palabras generadas: 23
# Número de palabras generadas: 22
# Generando caracteres para la fuente: MedievalSharp-regular (/content/fuentes/ocr_fonts_latin/MedievalSharp/MedievalSharp-regular.ttf)
# Número de palabras generadas: 24
# Número de palabras generadas: 26
# Generando caracteres para la fuente: Noto_Sans_Hanunoo-regular (/content/fuentes/ocr_fonts_latin/Noto_Sans_Hanunoo/Noto_Sans_Hanunoo-regular.ttf)
# Número de palabras generadas: 24
# Número de palabras generadas: 25
# Generando caracteres para la fuente: Noto_Sans_Linear_A-regular (/content/fuentes/ocr_fonts_latin/Noto_Sans_Linear_A/Noto_Sans_Linear_A-regular.ttf)
# Número de palabras generadas: 25
# Número de palabras generadas: 25
# Generando caracteres para la fuente: Martel-200 (/content/fuentes/ocr_fonts_latin/Martel/Martel-200.ttf)
# Número de palabras generadas: 25
# Número de palabras generadas: 30
# Generando caracteres para la fuente: Martel-800 (/content/fuentes/ocr_fonts_latin/Martel/Martel-800.ttf)
# Número de palabras generadas: 29
# Número de palabras generadas: 24
# Generando caracteres para la fuente: Martel-900 (/content/fuentes/ocr_fonts_latin/Martel/Martel-900.ttf)
# Número de palabras generadas: 24
# Número de palabras generadas: 22
# Generando caracteres para la fuente: Martel-regular (/content/fuentes/ocr_fonts_latin/Martel/Martel-regular.ttf)
# Número de palabras generadas: 24
# Número de palabras generadas: 24
# Generando caracteres para la fuente: Martel-700 (/content/fuentes/ocr_fonts_latin/Martel/Martel-700.ttf)
# Número de palabras generadas: 24
# Número de palabras generadas: 29
# Generando caracteres para la fuente: Martel-300 (/content/fuentes/ocr_fonts_latin/Martel/Martel-300.ttf)
# Número de palabras generadas: 24
# Número de palabras generadas: 29
# Generando caracteres para la fuente: Martel-600 (/content/fuentes/ocr_fonts_latin/Martel/Martel-600.ttf)
# Número de palabras generadas: 23
# Número de palabras generadas: 23
# Generando caracteres para la fuente: Noto_Sans_Bassa_Vah-regular (/content/fuentes/ocr_fonts_latin/Noto_Sans_Bassa_Vah/Noto_Sans_Bassa_Vah-regular.ttf)
# Número de palabras generadas: 24
# Número de palabras generadas: 23
# Generando caracteres para la fuente: Noto_Sans_Bassa_Vah-700 (/content/fuentes/ocr_fonts_latin/Noto_Sans_Bassa_Vah/Noto_Sans_Bassa_Vah-700.ttf)
# Número de palabras generadas: 24
# Número de palabras generadas: 22
# Generando caracteres para la fuente: Noto_Sans_Bassa_Vah-600 (/content/fuentes/ocr_fonts_latin/Noto_Sans_Bassa_Vah/Noto_Sans_Bassa_Vah-600.ttf)
# Número de palabras generadas: 25
# Número de palabras generadas: 25
# Generando caracteres para la fuente: Noto_Sans_Bassa_Vah-500 (/content/fuentes/ocr_fonts_latin/Noto_Sans_Bassa_Vah/Noto_Sans_Bassa_Vah-500.ttf)
# Número de palabras generadas: 24
# Número de palabras generadas: 22
# Generando caracteres para la fuente: Langar-regular (/content/fuentes/ocr_fonts_latin/Langar/Langar-regular.ttf)
# Número de palabras generadas: 25
# Número de palabras generadas: 23
# Generando caracteres para la fuente: Flavors-regular (/content/fuentes/ocr_fonts_latin/Flavors/Flavors-regular.ttf)
# Número de palabras generadas: 24
# Número de palabras generadas: 22
# Generando caracteres para la fuente: Noto_Sans_Mayan_Numerals-regular (/content/fuentes/ocr_fonts_latin/Noto_Sans_Mayan_Numerals/Noto_Sans_Mayan_Numerals-regular.ttf)
# Número de palabras generadas: 27
# Número de palabras generadas: 24
# Generando caracteres para la fuente: Mirza-600 (/content/fuentes/ocr_fonts_latin/Mirza/Mirza-600.ttf)
# Número de palabras generadas: 23
# Número de palabras generadas: 23
# Generando caracteres para la fuente: Mirza-500 (/content/fuentes/ocr_fonts_latin/Mirza/Mirza-500.ttf)
# Número de palabras generadas: 24
# Número de palabras generadas: 24
# Generando caracteres para la fuente: Mirza-700 (/content/fuentes/ocr_fonts_latin/Mirza/Mirza-700.ttf)
# Número de palabras generadas: 22
# Número de palabras generadas: 21
# Generando caracteres para la fuente: Mirza-regular (/content/fuentes/ocr_fonts_latin/Mirza/Mirza-regular.ttf)
# Número de palabras generadas: 20
# Número de palabras generadas: 23
# Generando caracteres para la fuente: Alatsi-regular (/content/fuentes/ocr_fonts_latin/Alatsi/Alatsi-regular.ttf)
# Número de palabras generadas: 20
# Número de palabras generadas: 20
# Generando caracteres para la fuente: Genos-800italic (/content/fuentes/ocr_fonts_latin/Genos/Genos-800italic.ttf)
# Número de palabras generadas: 28
# Número de palabras generadas: 27
# Generando caracteres para la fuente: Genos-700 (/content/fuentes/ocr_fonts_latin/Genos/Genos-700.ttf)
# Número de palabras generadas: 25
# Número de palabras generadas: 26
# Generando caracteres para la fuente: Genos-italic (/content/fuentes/ocr_fonts_latin/Genos/Genos-italic.ttf)
# Número de palabras generadas: 23
# Número de palabras generadas: 24
# Generando caracteres para la fuente: Genos-600 (/content/fuentes/ocr_fonts_latin/Genos/Genos-600.ttf)
# Número de palabras generadas: 29
# Número de palabras generadas: 25
# Generando caracteres para la fuente: Genos-500italic (/content/fuentes/ocr_fonts_latin/Genos/Genos-500italic.ttf)
# Número de palabras generadas: 26
# Número de palabras generadas: 25
# Generando caracteres para la fuente: Genos-200 (/content/fuentes/ocr_fonts_latin/Genos/Genos-200.ttf)
# Número de palabras generadas: 28
# Número de palabras generadas: 27
# Generando caracteres para la fuente: Genos-600italic (/content/fuentes/ocr_fonts_latin/Genos/Genos-600italic.ttf)
# Número de palabras generadas: 22
# Número de palabras generadas: 26
# Generando caracteres para la fuente: Genos-100italic (/content/fuentes/ocr_fonts_latin/Genos/Genos-100italic.ttf)
# Número de palabras generadas: 25
# Número de palabras generadas: 22
# Generando caracteres para la fuente: Genos-100 (/content/fuentes/ocr_fonts_latin/Genos/Genos-100.ttf)
# Número de palabras generadas: 23
# Número de palabras generadas: 27
# Generando caracteres para la fuente: Genos-300italic (/content/fuentes/ocr_fonts_latin/Genos/Genos-300italic.ttf)
# Número de palabras generadas: 25
# Número de palabras generadas: 25
# Generando caracteres para la fuente: Genos-300 (/content/fuentes/ocr_fonts_latin/Genos/Genos-300.ttf)
# Número de palabras generadas: 29
# Número de palabras generadas: 24
# Generando caracteres para la fuente: Genos-200italic (/content/fuentes/ocr_fonts_latin/Genos/Genos-200italic.ttf)
# Número de palabras generadas: 28
# Número de palabras generadas: 26
# Generando caracteres para la fuente: Genos-700italic (/content/fuentes/ocr_fonts_latin/Genos/Genos-700italic.ttf)
# Número de palabras generadas: 25
# Número de palabras generadas: 20
# Generando caracteres para la fuente: Genos-900 (/content/fuentes/ocr_fonts_latin/Genos/Genos-900.ttf)
# Número de palabras generadas: 26
# Número de palabras generadas: 23
# Generando caracteres para la fuente: Genos-900italic (/content/fuentes/ocr_fonts_latin/Genos/Genos-900italic.ttf)
# Número de palabras generadas: 26
# Número de palabras generadas: 29
# Generando caracteres para la fuente: Genos-regular (/content/fuentes/ocr_fonts_latin/Genos/Genos-regular.ttf)
# Número de palabras generadas: 23
# Número de palabras generadas: 24
# Generando caracteres para la fuente: Genos-800 (/content/fuentes/ocr_fonts_latin/Genos/Genos-800.ttf)
# Número de palabras generadas: 26
# Número de palabras generadas: 25
# Generando caracteres para la fuente: Genos-500 (/content/fuentes/ocr_fonts_latin/Genos/Genos-500.ttf)
# Número de palabras generadas: 26
# Número de palabras generadas: 31
# Generando caracteres para la fuente: Just_Another_Hand-regular (/content/fuentes/ocr_fonts_latin/Just_Another_Hand/Just_Another_Hand-regular.ttf)
# Número de palabras generadas: 25
# Número de palabras generadas: 23
# Generando caracteres para la fuente: Noto_Sans_Gunjala_Gondi-700 (/content/fuentes/ocr_fonts_latin/Noto_Sans_Gunjala_Gondi/Noto_Sans_Gunjala_Gondi-700.ttf)
# Número de palabras generadas: 25
# Número de palabras generadas: 24
# Generando caracteres para la fuente: Noto_Sans_Gunjala_Gondi-500 (/content/fuentes/ocr_fonts_latin/Noto_Sans_Gunjala_Gondi/Noto_Sans_Gunjala_Gondi-500.ttf)
# Número de palabras generadas: 23
# Número de palabras generadas: 23
# Generando caracteres para la fuente: Noto_Sans_Gunjala_Gondi-regular (/content/fuentes/ocr_fonts_latin/Noto_Sans_Gunjala_Gondi/Noto_Sans_Gunjala_Gondi-regular.ttf)
# Número de palabras generadas: 26
# Número de palabras generadas: 30
# Generando caracteres para la fuente: Noto_Sans_Gunjala_Gondi-600 (/content/fuentes/ocr_fonts_latin/Noto_Sans_Gunjala_Gondi/Noto_Sans_Gunjala_Gondi-600.ttf)
# Número de palabras generadas: 26
# Número de palabras generadas: 24
# Generando caracteres para la fuente: Edu_AU_VIC_WA_NT_Hand-500 (/content/fuentes/ocr_fonts_latin/Edu_AU_VIC_WA_NT_Hand/Edu_AU_VIC_WA_NT_Hand-500.ttf)
# Número de palabras generadas: 25
# Número de palabras generadas: 27
# Generando caracteres para la fuente: Edu_AU_VIC_WA_NT_Hand-600 (/content/fuentes/ocr_fonts_latin/Edu_AU_VIC_WA_NT_Hand/Edu_AU_VIC_WA_NT_Hand-600.ttf)
# Número de palabras generadas: 25
# Número de palabras generadas: 27
# Generando caracteres para la fuente: Edu_AU_VIC_WA_NT_Hand-700 (/content/fuentes/ocr_fonts_latin/Edu_AU_VIC_WA_NT_Hand/Edu_AU_VIC_WA_NT_Hand-700.ttf)
# Número de palabras generadas: 27
# Número de palabras generadas: 26
# Generando caracteres para la fuente: Edu_AU_VIC_WA_NT_Hand-regular (/content/fuentes/ocr_fonts_latin/Edu_AU_VIC_WA_NT_Hand/Edu_AU_VIC_WA_NT_Hand-regular.ttf)
# Número de palabras generadas: 26
# Número de palabras generadas: 27
# Generando caracteres para la fuente: Caramel-regular (/content/fuentes/ocr_fonts_latin/Caramel/Caramel-regular.ttf)
# Número de palabras generadas: 24
# Número de palabras generadas: 24
# Generando caracteres para la fuente: Laila-600 (/content/fuentes/ocr_fonts_latin/Laila/Laila-600.ttf)
# Número de palabras generadas: 25
# Número de palabras generadas: 32
# Generando caracteres para la fuente: Laila-700 (/content/fuentes/ocr_fonts_latin/Laila/Laila-700.ttf)
# Número de palabras generadas: 24
# Número de palabras generadas: 24
# Generando caracteres para la fuente: Laila-500 (/content/fuentes/ocr_fonts_latin/Laila/Laila-500.ttf)
# Número de palabras generadas: 23
# Número de palabras generadas: 24
# Generando caracteres para la fuente: Laila-300 (/content/fuentes/ocr_fonts_latin/Laila/Laila-300.ttf)
# Número de palabras generadas: 25
# Número de palabras generadas: 25
# Generando caracteres para la fuente: Laila-regular (/content/fuentes/ocr_fonts_latin/Laila/Laila-regular.ttf)
# Número de palabras generadas: 25
# Número de palabras generadas: 26
# Generando caracteres para la fuente: Alike-regular (/content/fuentes/ocr_fonts_latin/Alike/Alike-regular.ttf)
# Número de palabras generadas: 22
# Número de palabras generadas: 24
# Generando caracteres para la fuente: Manjari-regular (/content/fuentes/ocr_fonts_latin/Manjari/Manjari-regular.ttf)
# Número de palabras generadas: 25
# Número de palabras generadas: 25
# Generando caracteres para la fuente: Manjari-100 (/content/fuentes/ocr_fonts_latin/Manjari/Manjari-100.ttf)
# Número de palabras generadas: 25
# Número de palabras generadas: 27
# Generando caracteres para la fuente: Manjari-700 (/content/fuentes/ocr_fonts_latin/Manjari/Manjari-700.ttf)
# Número de palabras generadas: 25
# Número de palabras generadas: 25
# Generando caracteres para la fuente: Cormorant_Infant-600italic (/content/fuentes/ocr_fonts_latin/Cormorant_Infant/Cormorant_Infant-600italic.ttf)
# Número de palabras generadas: 23
# Número de palabras generadas: 24
# Generando caracteres para la fuente: Cormorant_Infant-regular (/content/fuentes/ocr_fonts_latin/Cormorant_Infant/Cormorant_Infant-regular.ttf)
# Número de palabras generadas: 30
# Número de palabras generadas: 23
# Generando caracteres para la fuente: Cormorant_Infant-600 (/content/fuentes/ocr_fonts_latin/Cormorant_Infant/Cormorant_Infant-600.ttf)
# Número de palabras generadas: 24
# Número de palabras generadas: 21
# Generando caracteres para la fuente: Cormorant_Infant-500italic (/content/fuentes/ocr_fonts_latin/Cormorant_Infant/Cormorant_Infant-500italic.ttf)
# Número de palabras generadas: 23
# Número de palabras generadas: 23
# Generando caracteres para la fuente: Cormorant_Infant-500 (/content/fuentes/ocr_fonts_latin/Cormorant_Infant/Cormorant_Infant-500.ttf)
# Número de palabras generadas: 27
# Número de palabras generadas: 28
# Generando caracteres para la fuente: Cormorant_Infant-700italic (/content/fuentes/ocr_fonts_latin/Cormorant_Infant/Cormorant_Infant-700italic.ttf)
# Número de palabras generadas: 26
# Número de palabras generadas: 22
# Generando caracteres para la fuente: Cormorant_Infant-300italic (/content/fuentes/ocr_fonts_latin/Cormorant_Infant/Cormorant_Infant-300italic.ttf)
# Número de palabras generadas: 22
# Número de palabras generadas: 29
# Generando caracteres para la fuente: Cormorant_Infant-700 (/content/fuentes/ocr_fonts_latin/Cormorant_Infant/Cormorant_Infant-700.ttf)
# Número de palabras generadas: 22
# Número de palabras generadas: 26
# Generando caracteres para la fuente: Cormorant_Infant-300 (/content/fuentes/ocr_fonts_latin/Cormorant_Infant/Cormorant_Infant-300.ttf)
# Número de palabras generadas: 25
# Número de palabras generadas: 26
# Generando caracteres para la fuente: Cormorant_Infant-italic (/content/fuentes/ocr_fonts_latin/Cormorant_Infant/Cormorant_Infant-italic.ttf)
# Número de palabras generadas: 26
# Número de palabras generadas: 28
# Generando caracteres para la fuente: Montagu_Slab-200 (/content/fuentes/ocr_fonts_latin/Montagu_Slab/Montagu_Slab-200.ttf)
# Número de palabras generadas: 24
# Número de palabras generadas: 24
# Generando caracteres para la fuente: Montagu_Slab-700 (/content/fuentes/ocr_fonts_latin/Montagu_Slab/Montagu_Slab-700.ttf)
# Número de palabras generadas: 26
# Número de palabras generadas: 23
# Generando caracteres para la fuente: Montagu_Slab-300 (/content/fuentes/ocr_fonts_latin/Montagu_Slab/Montagu_Slab-300.ttf)
# Número de palabras generadas: 22
# Número de palabras generadas: 27
# Generando caracteres para la fuente: Montagu_Slab-600 (/content/fuentes/ocr_fonts_latin/Montagu_Slab/Montagu_Slab-600.ttf)
# Número de palabras generadas: 24
# Número de palabras generadas: 25
# Generando caracteres para la fuente: Montagu_Slab-100 (/content/fuentes/ocr_fonts_latin/Montagu_Slab/Montagu_Slab-100.ttf)
# Número de palabras generadas: 27
# Número de palabras generadas: 23
# Generando caracteres para la fuente: Montagu_Slab-500 (/content/fuentes/ocr_fonts_latin/Montagu_Slab/Montagu_Slab-500.ttf)
# Número de palabras generadas: 26
# Número de palabras generadas: 27
# Generando caracteres para la fuente: Montagu_Slab-regular (/content/fuentes/ocr_fonts_latin/Montagu_Slab/Montagu_Slab-regular.ttf)
# Número de palabras generadas: 25
# Número de palabras generadas: 24
# Generando caracteres para la fuente: Bruno_Ace_SC-regular (/content/fuentes/ocr_fonts_latin/Bruno_Ace_SC/Bruno_Ace_SC-regular.ttf)
# Número de palabras generadas: 24
# Número de palabras generadas: 23
# Generando caracteres para la fuente: Fustat-700 (/content/fuentes/ocr_fonts_latin/Fustat/Fustat-700.ttf)
# Número de palabras generadas: 24
# Número de palabras generadas: 27
# Generando caracteres para la fuente: Fustat-regular (/content/fuentes/ocr_fonts_latin/Fustat/Fustat-regular.ttf)
# Número de palabras generadas: 28
# Número de palabras generadas: 24
# Generando caracteres para la fuente: Fustat-600 (/content/fuentes/ocr_fonts_latin/Fustat/Fustat-600.ttf)
# Número de palabras generadas: 23
# Número de palabras generadas: 26
# Generando caracteres para la fuente: Fustat-500 (/content/fuentes/ocr_fonts_latin/Fustat/Fustat-500.ttf)
# Número de palabras generadas: 22
# Número de palabras generadas: 24
# Generando caracteres para la fuente: Fustat-800 (/content/fuentes/ocr_fonts_latin/Fustat/Fustat-800.ttf)
# Número de palabras generadas: 25
# Número de palabras generadas: 25
# Generando caracteres para la fuente: Fustat-300 (/content/fuentes/ocr_fonts_latin/Fustat/Fustat-300.ttf)
# Número de palabras generadas: 23
# Número de palabras generadas: 23
# ...
# Número de palabras generadas: 25
# Número de palabras generadas: 28
# Generando caracteres para la fuente: Maname-regular (/content/fuentes/ocr_fonts_latin/Maname/Maname-regular.ttf)
# Número de palabras generadas: 24
# Número de palabras generadas: 22
# Generando caracteres para la fuente: Jersey_15_Charted-regular (/content/fuentes/ocr_fonts_latin/Jersey_15_Charted/Jersey_15_Charted-regular.ttf)
# Número de palabras generadas: 27
# Número de palabras generadas: 26
# Generando caracteres para la fuente: Marck_Script-regular (/content/fuentes/ocr_fonts_latin/Marck_Script/Marck_Script-regular.ttf)
# Número de palabras generadas: 28
# Número de palabras generadas: 24
# Generando caracteres para la fuente: Bad_Script-regular (/content/fuentes/ocr_fonts_latin/Bad_Script/Bad_Script-regular.ttf)
# Número de palabras generadas: 24
# Número de palabras generadas: 25
# Generando caracteres para la fuente: Kavivanar-regular (/content/fuentes/ocr_fonts_latin/Kavivanar/Kavivanar-regular.ttf)
# Número de palabras generadas: 25
# Número de palabras generadas: 24
# Generando caracteres para la fuente: Arsenal_SC-700italic (/content/fuentes/ocr_fonts_latin/Arsenal_SC/Arsenal_SC-700italic.ttf)
# Número de palabras generadas: 27
# Número de palabras generadas: 24
# Generando caracteres para la fuente: Arsenal_SC-700 (/content/fuentes/ocr_fonts_latin/Arsenal_SC/Arsenal_SC-700.ttf)
# Número de palabras generadas: 23
# Número de palabras generadas: 21
# Generando caracteres para la fuente: Arsenal_SC-regular (/content/fuentes/ocr_fonts_latin/Arsenal_SC/Arsenal_SC-regular.ttf)
# Número de palabras generadas: 23
# Número de palabras generadas: 26
# Generando caracteres para la fuente: Arsenal_SC-italic (/content/fuentes/ocr_fonts_latin/Arsenal_SC/Arsenal_SC-italic.ttf)
# Número de palabras generadas: 27
# Número de palabras generadas: 26
# Generando caracteres para la fuente: Gajraj_One-regular (/content/fuentes/ocr_fonts_latin/Gajraj_One/Gajraj_One-regular.ttf)
# Número de palabras generadas: 26
# Número de palabras generadas: 27
# Generando caracteres para la fuente: DM_Serif_Display-italic (/content/fuentes/ocr_fonts_latin/DM_Serif_Display/DM_Serif_Display-italic.ttf)
# Número de palabras generadas: 22
# Número de palabras generadas: 26
# Generando caracteres para la fuente: DM_Serif_Display-regular (/content/fuentes/ocr_fonts_latin/DM_Serif_Display/DM_Serif_Display-regular.ttf)
# Número de palabras generadas: 26
# Número de palabras generadas: 22
# Generando caracteres para la fuente: Liter-regular (/content/fuentes/ocr_fonts_latin/Liter/Liter-regular.ttf)
# Número de palabras generadas: 24
# Número de palabras generadas: 26
# Generando caracteres para la fuente: Noto_Sans_Egyptian_Hieroglyphs-regular (/content/fuentes/ocr_fonts_latin/Noto_Sans_Egyptian_Hieroglyphs/Noto_Sans_Egyptian_Hieroglyphs-regular.ttf)
# Número de palabras generadas: 23
# Número de palabras generadas: 26
# Generando caracteres para la fuente: Almendra-regular (/content/fuentes/ocr_fonts_latin/Almendra/Almendra-regular.ttf)
# Número de palabras generadas: 19
# Número de palabras generadas: 24
# Generando caracteres para la fuente: Almendra-700 (/content/fuentes/ocr_fonts_latin/Almendra/Almendra-700.ttf)
# Número de palabras generadas: 22
# Número de palabras generadas: 26
# Generando caracteres para la fuente: Almendra-700italic (/content/fuentes/ocr_fonts_latin/Almendra/Almendra-700italic.ttf)
# Número de palabras generadas: 31
# Número de palabras generadas: 25
# Generando caracteres para la fuente: Almendra-italic (/content/fuentes/ocr_fonts_latin/Almendra/Almendra-italic.ttf)
# Número de palabras generadas: 26
# Número de palabras generadas: 26
# Generando caracteres para la fuente: Corinthia-regular (/content/fuentes/ocr_fonts_latin/Corinthia/Corinthia-regular.ttf)
# Número de palabras generadas: 24
# Número de palabras generadas: 26
# Generando caracteres para la fuente: Corinthia-700 (/content/fuentes/ocr_fonts_latin/Corinthia/Corinthia-700.ttf)
# Número de palabras generadas: 28
# Número de palabras generadas: 24
# Generando caracteres para la fuente: Be_Vietnam_Pro-100italic (/content/fuentes/ocr_fonts_latin/Be_Vietnam_Pro/Be_Vietnam_Pro-100italic.ttf)
# Número de palabras generadas: 27
# Número de palabras generadas: 23
# Generando caracteres para la fuente: Be_Vietnam_Pro-600 (/content/fuentes/ocr_fonts_latin/Be_Vietnam_Pro/Be_Vietnam_Pro-600.ttf)
# Número de palabras generadas: 23
# Número de palabras generadas: 25
# Generando caracteres para la fuente: Be_Vietnam_Pro-700italic (/content/fuentes/ocr_fonts_latin/Be_Vietnam_Pro/Be_Vietnam_Pro-700italic.ttf)
# Número de palabras generadas: 28
# Número de palabras generadas: 27
# Generando caracteres para la fuente: Be_Vietnam_Pro-500italic (/content/fuentes/ocr_fonts_latin/Be_Vietnam_Pro/Be_Vietnam_Pro-500italic.ttf)
# Número de palabras generadas: 23
# Número de palabras generadas: 24
# Generando caracteres para la fuente: Be_Vietnam_Pro-100 (/content/fuentes/ocr_fonts_latin/Be_Vietnam_Pro/Be_Vietnam_Pro-100.ttf)
# Número de palabras generadas: 23
# Número de palabras generadas: 24
# Generando caracteres para la fuente: Be_Vietnam_Pro-regular (/content/fuentes/ocr_fonts_latin/Be_Vietnam_Pro/Be_Vietnam_Pro-regular.ttf)
# Número de palabras generadas: 26
# Número de palabras generadas: 24
# Generando caracteres para la fuente: Be_Vietnam_Pro-300 (/content/fuentes/ocr_fonts_latin/Be_Vietnam_Pro/Be_Vietnam_Pro-300.ttf)
# Número de palabras generadas: 28
# Número de palabras generadas: 25
# Generando caracteres para la fuente: Be_Vietnam_Pro-800 (/content/fuentes/ocr_fonts_latin/Be_Vietnam_Pro/Be_Vietnam_Pro-800.ttf)
# Número de palabras generadas: 27
# Número de palabras generadas: 24
# Generando caracteres para la fuente: Be_Vietnam_Pro-800italic (/content/fuentes/ocr_fonts_latin/Be_Vietnam_Pro/Be_Vietnam_Pro-800italic.ttf)
# Número de palabras generadas: 22
# Número de palabras generadas: 23
# Generando caracteres para la fuente: Be_Vietnam_Pro-600italic (/content/fuentes/ocr_fonts_latin/Be_Vietnam_Pro/Be_Vietnam_Pro-600italic.ttf)
# Número de palabras generadas: 24
# Número de palabras generadas: 24
# Generando caracteres para la fuente: Be_Vietnam_Pro-300italic (/content/fuentes/ocr_fonts_latin/Be_Vietnam_Pro/Be_Vietnam_Pro-300italic.ttf)
# Número de palabras generadas: 23
# Número de palabras generadas: 27
# Generando caracteres para la fuente: Be_Vietnam_Pro-200 (/content/fuentes/ocr_fonts_latin/Be_Vietnam_Pro/Be_Vietnam_Pro-200.ttf)
# Número de palabras generadas: 24
# Número de palabras generadas: 25
# Generando caracteres para la fuente: Be_Vietnam_Pro-500 (/content/fuentes/ocr_fonts_latin/Be_Vietnam_Pro/Be_Vietnam_Pro-500.ttf)
# Número de palabras generadas: 22
# Número de palabras generadas: 24
# Generando caracteres para la fuente: Be_Vietnam_Pro-900 (/content/fuentes/ocr_fonts_latin/Be_Vietnam_Pro/Be_Vietnam_Pro-900.ttf)
# Número de palabras generadas: 25
# Número de palabras generadas: 23
# Generando caracteres para la fuente: Be_Vietnam_Pro-200italic (/content/fuentes/ocr_fonts_latin/Be_Vietnam_Pro/Be_Vietnam_Pro-200italic.ttf)
# Número de palabras generadas: 23
# Número de palabras generadas: 25
# Generando caracteres para la fuente: Be_Vietnam_Pro-italic (/content/fuentes/ocr_fonts_latin/Be_Vietnam_Pro/Be_Vietnam_Pro-italic.ttf)
# Número de palabras generadas: 27
# Número de palabras generadas: 23
# Generando caracteres para la fuente: Be_Vietnam_Pro-900italic (/content/fuentes/ocr_fonts_latin/Be_Vietnam_Pro/Be_Vietnam_Pro-900italic.ttf)
# Número de palabras generadas: 26
# Número de palabras generadas: 24
# Generando caracteres para la fuente: Be_Vietnam_Pro-700 (/content/fuentes/ocr_fonts_latin/Be_Vietnam_Pro/Be_Vietnam_Pro-700.ttf)
# Número de palabras generadas: 25
# Número de palabras generadas: 22
# Generando caracteres para la fuente: Kiwi_Maru-regular (/content/fuentes/ocr_fonts_latin/Kiwi_Maru/Kiwi_Maru-regular.ttf)
# Número de palabras generadas: 26
# Número de palabras generadas: 22
# Generando caracteres para la fuente: Kiwi_Maru-500 (/content/fuentes/ocr_fonts_latin/Kiwi_Maru/Kiwi_Maru-500.ttf)
# Número de palabras generadas: 26
# Número de palabras generadas: 25
# Generando caracteres para la fuente: Kiwi_Maru-300 (/content/fuentes/ocr_fonts_latin/Kiwi_Maru/Kiwi_Maru-300.ttf)
# Número de palabras generadas: 23
# Número de palabras generadas: 24
# Generando caracteres para la fuente: Mada-regular (/content/fuentes/ocr_fonts_latin/Mada/Mada-regular.ttf)
# Número de palabras generadas: 25
# Número de palabras generadas: 22
# Generando caracteres para la fuente: Mada-500 (/content/fuentes/ocr_fonts_latin/Mada/Mada-500.ttf)
# Número de palabras generadas: 26
# Número de palabras generadas: 22
# Generando caracteres para la fuente: Mada-900 (/content/fuentes/ocr_fonts_latin/Mada/Mada-900.ttf)
# Número de palabras generadas: 24
# Número de palabras generadas: 21
# Generando caracteres para la fuente: Mada-300 (/content/fuentes/ocr_fonts_latin/Mada/Mada-300.ttf)
# Número de palabras generadas: 26
# Número de palabras generadas: 28
# Generando caracteres para la fuente: Mada-800 (/content/fuentes/ocr_fonts_latin/Mada/Mada-800.ttf)
# Número de palabras generadas: 23
# Número de palabras generadas: 26
# Generando caracteres para la fuente: Mada-700 (/content/fuentes/ocr_fonts_latin/Mada/Mada-700.ttf)
# Número de palabras generadas: 23
# Número de palabras generadas: 23
# Generando caracteres para la fuente: Mada-600 (/content/fuentes/ocr_fonts_latin/Mada/Mada-600.ttf)
# Número de palabras generadas: 23
# Número de palabras generadas: 27
# Generando caracteres para la fuente: Mada-200 (/content/fuentes/ocr_fonts_latin/Mada/Mada-200.ttf)
# Número de palabras generadas: 21
# Número de palabras generadas: 26
# Generando caracteres para la fuente: Gentium_Plus-700 (/content/fuentes/ocr_fonts_latin/Gentium_Plus/Gentium_Plus-700.ttf)
# Número de palabras generadas: 29
# Número de palabras generadas: 26
# Generando caracteres para la fuente: Gentium_Plus-italic (/content/fuentes/ocr_fonts_latin/Gentium_Plus/Gentium_Plus-italic.ttf)
# Número de palabras generadas: 28
# Número de palabras generadas: 25
# Generando caracteres para la fuente: Gentium_Plus-regular (/content/fuentes/ocr_fonts_latin/Gentium_Plus/Gentium_Plus-regular.ttf)
# Número de palabras generadas: 27
# Número de palabras generadas: 25
# Generando caracteres para la fuente: Gentium_Plus-700italic (/content/fuentes/ocr_fonts_latin/Gentium_Plus/Gentium_Plus-700italic.ttf)
# Número de palabras generadas: 24
# Número de palabras generadas: 21
# Generando caracteres para la fuente: Kalam-300 (/content/fuentes/ocr_fonts_latin/Kalam/Kalam-300.ttf)
# Número de palabras generadas: 22
# Número de palabras generadas: 27
# Generando caracteres para la fuente: Kalam-regular (/content/fuentes/ocr_fonts_latin/Kalam/Kalam-regular.ttf)
# Número de palabras generadas: 26
# Número de palabras generadas: 25
# Generando caracteres para la fuente: Kalam-700 (/content/fuentes/ocr_fonts_latin/Kalam/Kalam-700.ttf)
# Número de palabras generadas: 27
# Número de palabras generadas: 22
# Generando caracteres para la fuente: Butterfly_Kids-regular (/content/fuentes/ocr_fonts_latin/Butterfly_Kids/Butterfly_Kids-regular.ttf)
# Número de palabras generadas: 25
# Número de palabras generadas: 25
# Generando caracteres para la fuente: Jaldi-700 (/content/fuentes/ocr_fonts_latin/Jaldi/Jaldi-700.ttf)
# Número de palabras generadas: 24
# Número de palabras generadas: 23
# Generando caracteres para la fuente: Jaldi-regular (/content/fuentes/ocr_fonts_latin/Jaldi/Jaldi-regular.ttf)
# Número de palabras generadas: 25
# Número de palabras generadas: 28
# Generando caracteres para la fuente: Ancizar_Serif-500italic (/content/fuentes/ocr_fonts_latin/Ancizar_Serif/Ancizar_Serif-500italic.ttf)
# Número de palabras generadas: 23
# Número de palabras generadas: 26
# Generando caracteres para la fuente: Ancizar_Serif-300italic (/content/fuentes/ocr_fonts_latin/Ancizar_Serif/Ancizar_Serif-300italic.ttf)
# Número de palabras generadas: 24
# Número de palabras generadas: 24
# Generando caracteres para la fuente: Ancizar_Serif-500 (/content/fuentes/ocr_fonts_latin/Ancizar_Serif/Ancizar_Serif-500.ttf)
# Número de palabras generadas: 26
# Número de palabras generadas: 22
# Generando caracteres para la fuente: Ancizar_Serif-900 (/content/fuentes/ocr_fonts_latin/Ancizar_Serif/Ancizar_Serif-900.ttf)
# Número de palabras generadas: 24
# Número de palabras generadas: 21
# Generando caracteres para la fuente: Ancizar_Serif-800italic (/content/fuentes/ocr_fonts_latin/Ancizar_Serif/Ancizar_Serif-800italic.ttf)
# Número de palabras generadas: 25
# Número de palabras generadas: 24
# Generando caracteres para la fuente: Ancizar_Serif-700 (/content/fuentes/ocr_fonts_latin/Ancizar_Serif/Ancizar_Serif-700.ttf)
# Número de palabras generadas: 23
# Número de palabras generadas: 27
# Generando caracteres para la fuente: Ancizar_Serif-300 (/content/fuentes/ocr_fonts_latin/Ancizar_Serif/Ancizar_Serif-300.ttf)
# Número de palabras generadas: 21
# Número de palabras generadas: 23
# Generando caracteres para la fuente: Ancizar_Serif-800 (/content/fuentes/ocr_fonts_latin/Ancizar_Serif/Ancizar_Serif-800.ttf)
# Número de palabras generadas: 23
# Número de palabras generadas: 24
# Generando caracteres para la fuente: Ancizar_Serif-italic (/content/fuentes/ocr_fonts_latin/Ancizar_Serif/Ancizar_Serif-italic.ttf)
# Número de palabras generadas: 24
# Número de palabras generadas: 21
# Generando caracteres para la fuente: Ancizar_Serif-600italic (/content/fuentes/ocr_fonts_latin/Ancizar_Serif/Ancizar_Serif-600italic.ttf)
# Número de palabras generadas: 22
# Número de palabras generadas: 29
# Generando caracteres para la fuente: Ancizar_Serif-regular (/content/fuentes/ocr_fonts_latin/Ancizar_Serif/Ancizar_Serif-regular.ttf)
# Número de palabras generadas: 24
# Número de palabras generadas: 27
# Generando caracteres para la fuente: Ancizar_Serif-600 (/content/fuentes/ocr_fonts_latin/Ancizar_Serif/Ancizar_Serif-600.ttf)
# Número de palabras generadas: 21
# Número de palabras generadas: 23
# Generando caracteres para la fuente: Ancizar_Serif-900italic (/content/fuentes/ocr_fonts_latin/Ancizar_Serif/Ancizar_Serif-900italic.ttf)
# Número de palabras generadas: 24
# Número de palabras generadas: 22
# Generando caracteres para la fuente: Ancizar_Serif-700italic (/content/fuentes/ocr_fonts_latin/Ancizar_Serif/Ancizar_Serif-700italic.ttf)
# Número de palabras generadas: 23
# Número de palabras generadas: 27
# Generando caracteres para la fuente: LXGW_WenKai_TC-300 (/content/fuentes/ocr_fonts_latin/LXGW_WenKai_TC/LXGW_WenKai_TC-300.ttf)
# Número de palabras generadas: 24
# Número de palabras generadas: 27
# Generando caracteres para la fuente: LXGW_WenKai_TC-regular (/content/fuentes/ocr_fonts_latin/LXGW_WenKai_TC/LXGW_WenKai_TC-regular.ttf)
# Número de palabras generadas: 21
# Número de palabras generadas: 23
# Generando caracteres para la fuente: LXGW_WenKai_TC-700 (/content/fuentes/ocr_fonts_latin/LXGW_WenKai_TC/LXGW_WenKai_TC-700.ttf)
# Número de palabras generadas: 25
# Número de palabras generadas: 26
# Generando caracteres para la fuente: Noto_Sans_Medefaidrin-700 (/content/fuentes/ocr_fonts_latin/Noto_Sans_Medefaidrin/Noto_Sans_Medefaidrin-700.ttf)
# Número de palabras generadas: 24
# Número de palabras generadas: 24
# Generando caracteres para la fuente: Noto_Sans_Medefaidrin-600 (/content/fuentes/ocr_fonts_latin/Noto_Sans_Medefaidrin/Noto_Sans_Medefaidrin-600.ttf)
# Número de palabras generadas: 25
# Número de palabras generadas: 26
# Generando caracteres para la fuente: Noto_Sans_Medefaidrin-regular (/content/fuentes/ocr_fonts_latin/Noto_Sans_Medefaidrin/Noto_Sans_Medefaidrin-regular.ttf)
# Número de palabras generadas: 21
# Número de palabras generadas: 23
# Generando caracteres para la fuente: Noto_Sans_Medefaidrin-500 (/content/fuentes/ocr_fonts_latin/Noto_Sans_Medefaidrin/Noto_Sans_Medefaidrin-500.ttf)
# Número de palabras generadas: 26
# Número de palabras generadas: 25
# Generando caracteres para la fuente: League_Gothic-regular (/content/fuentes/ocr_fonts_latin/League_Gothic/League_Gothic-regular.ttf)
# Número de palabras generadas: 25
# Número de palabras generadas: 22
# Generando caracteres para la fuente: Bahianita-regular (/content/fuentes/ocr_fonts_latin/Bahianita/Bahianita-regular.ttf)
# Número de palabras generadas: 24
# Número de palabras generadas: 24
# Total de palabras a generar: 193136

# %% [markdown]
# ## Generacion de las imagenes con las palabras

# %%
# prompt: quiero una funcion que reciba una imagen de cv en escala de grises y le aplique blur gausieano y la devuelva en el mismo formato

def apply_gaussian_blur(image_gray, ksize=(3, 3), sigmaX=0):
    """
    Aplica un filtro de desenfoque Gaussiano a una imagen en escala de grises.

    Args:
        image_gray (np.ndarray): Imagen de entrada en escala de grises (array NumPy).
        ksize (tuple): Tamaño del kernel Gaussiano. Debe ser una tupla de números
                       enteros impares positivos (ancho, alto).
        sigmaX (float): Desviación estándar del kernel en la dirección X. Si es 0,
                        se calcula automáticamente en función del tamaño del kernel.

    Returns:
        np.ndarray: La imagen desenfocada como un array NumPy en escala de grises.
    """
    if len(image_gray.shape) != 2:
        print("Advertencia: La imagen de entrada no está en escala de grises. Intentando convertir.")
        image_gray = cv2.cvtColor(image_gray, cv2.COLOR_BGR2GRAY)

    blurred_image = cv2.GaussianBlur(image_gray, ksize, sigmaX)
    return blurred_image

def invert_image(image):
    """
    Invierte la imagen en escala de grises.
    """
    return 255 - image

# %%
def obtener_dimensiones_contorno_caracter(caracter:str, ruta_fuente:str, tamano_fuente:int):

    # Dimensiones de la imagen base (suficientemente grande para cualquier caracter)
    img_width, img_height = tamano_fuente * 2, tamano_fuente * 2

    # Crear una imagen en blanco con fondo negro
    img = Image.new('L', (img_width, img_height), color=0) # 'L' para escala de grises
    d = ImageDraw.Draw(img)

    font = ImageFont.truetype(ruta_fuente, tamano_fuente)

    # Calcular el tamaño del texto para centrarlo
    bbox = d.textbbox((0,0), caracter, font=font)
    text_width = bbox[2] - bbox[0]
    text_height = bbox[3] - bbox[1]

    # Calcular la posición para centrar el texto
    x = (img_width - text_width) // 2
    y = (img_height - text_height) // 2

    # Dibujar el caracter en blanco sobre fondo negro
    d.text((x, y), caracter, font=font, fill=255)

    # Convertir la imagen de Pillow a un array de NumPy para OpenCV
    img_np = np.array(img)

    # Encontrar contornos
    contours, _ = cv2.findContours(img_np, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    if not contours:
        return 0, 0  # No se encontraron contornos

    all_points = np.vstack(contours)
    # Encontrar el rectángulo delimitador para el contorno combinado
    x, y, w, h = cv2.boundingRect(all_points)
    return x, y, w, h

# %%
import math
def generar_imagen_multifuente(palabras_fuentes, palabras_a_generar, tamanio_imagen, rango_separacion_caracteres, rango_separacion_lineas, rango_tamanio_fuente, output_path=None):

    # Configuración base
    img_size = tamanio_imagen
    margen = 10 #Ajustar a gusto
    fuentes_erroneas=[]

    # Seleccionar parámetros comunes para toda la imagen
    tamano_fuente = random.randint(*rango_tamanio_fuente)
    separacion_lineas = random.randint(*rango_separacion_lineas)
    espaciado_caracteres = random.randint(*rango_separacion_caracteres)

    # Crear imagen PIL (fondo negro)
    img_pil = Image.new('L', (img_size, img_size), color=0)
    draw = ImageDraw.Draw(img_pil)

    # Listas para resultados
    bboxes = []
    caracteres = []

    # Pre-calcular altura total
    alto_total = len(palabras_fuentes) * tamano_fuente + (len(palabras_fuentes) - 1) * separacion_lineas
    y_actual = (img_size - alto_total) // 2

    # Procesar cada palabra con su fuente
    for idx, row in palabras_fuentes.iterrows():
        palabra = row['palabra']
        fuente = row['font_name']
        ruta_fuente = row['font_path']
        try:
            font = ImageFont.truetype(ruta_fuente, tamano_fuente)
        except Exception as e:
            fuentes_erroneas.append(ruta_fuente)
            print(f"Error cargando fuente {ruta_fuente}: {str(e)}")
            continue
        # Calcular ancho de la palabra con espaciado
        try:
            ancho_palabra = sum(draw.textlength(c, font=font) + espaciado_caracteres for c in palabra) - espaciado_caracteres
        except:
            print(f"error calculando el ancho para la fuente {fuente}")
            fuentes_erroneas.append(ruta_fuente)
            continue
        # Si la palabra excede el ancho permitido ajusto los valores a los minimos
        if ancho_palabra <= img_size - margen*2:
            tamano_fuente = rango_tamanio_fuente[0]
            espaciado_caracteres = rango_separacion_caracteres[0]
            font = ImageFont.truetype(ruta_fuente, tamano_fuente)
            ancho_palabra = sum(draw.textlength(c, font=font) + espaciado_caracteres for c in palabra) - espaciado_caracteres

        # Posición horizontal (centrado)
        x_actual = (img_size - ancho_palabra) // 2

        # Procesar cada caracter
        for caracter in palabra:
            try:
                # Calcular bbox
                left, top, right, bottom = font.getbbox(caracter)
                ancho_car = draw.textlength(caracter, font=font)
                ancho_car = int(math.ceil(ancho_car))
                _, _, ancho_real, _ = obtener_dimensiones_contorno_caracter(caracter, ruta_fuente, tamano_fuente)
                x_caja = x_actual - abs(max(ancho_real,right,ancho_car) - min(ancho_real,right,ancho_car))
                bbox = [
                    int(max(x_caja,1)),
                    int(y_actual + top),
                    int(x_actual + max(ancho_real, ancho_car, right)),
                    int(y_actual + bottom)
                ]
                if x_caja <= 0 or x_actual + max(ancho_real, ancho_car, right) >= (img_size - 20):
                    print(f"palabra exedida del ancho: {palabra} - fuente: {fuente}")
                bboxes.append(bbox)
                caracteres.append(caracter)

                # Dibujar caracter
                draw.text(
                    (x_actual, y_actual),
                    caracter,
                    font=font,
                    fill=255
                )

                # Mover posición horizontal
                x_actual += max(ancho_real, ancho_car, right) + espaciado_caracteres
            except:
                print(f"no se pudo procesar el cacarcter '{caracter}' para la fuente {fuente}")
                fuentes_erroneas.append(ruta_fuente)

        # Mover posición vertical
        y_actual += tamano_fuente + separacion_lineas

    # Convertir a OpenCV
    img_cv2 = np.array(img_pil)

    #aplico blur al 20%
    if random.random() < 0.2:
        img_cv2 = apply_gaussian_blur(img_cv2)

    #invierto colores al 20%
    if random.random() < 0.2:
        img_cv2 = invert_image(img_cv2)

    #Si se definio carpeta de salida guarda la imagen
    if output_path:
        cv2.imwrite(output_path, img_cv2)

    #- Opcional: Elimina las fuentes con errores o que no reconocen todo el diccionario
    if fuentes_erroneas:
        for fuente in fuentes_erroneas:
            try:
                #path_corregido = fuente.replace('/', '\\') para windows
                path_corregido = fuente.replace('\\', '/') #para linux o colab
                os.remove(path_corregido)
                print(f"fuente {path_corregido} eliminada")
            except: # si no funciona pruebo por linea de comandos
                try:
                    #!del /f /q "{path_corregido}" #para windows
                    # !rm -f "{path_corregido}" #para linux o colab
                    print(f"fuente {path_corregido} eliminada")
                except:
                    print(f"no se pudo eliminar la fuente {path_corregido}")
            palabras_a_generar = palabras_a_generar[palabras_a_generar['font_path'] != fuente]

    return img_cv2, bboxes, caracteres, palabras_a_generar

# %%
info_imagenes = []
data_imagenes = []
index_imagen = 0
palabras_generadas = 0
index_actual = 0

print(f"Total de palabras a generar: {len(palabras_a_generar)}")
if len(palabras_a_generar) > 0:
    while index_actual < len(palabras_a_generar):
        if index_actual % 1000 == 0:
            print(f"{index_actual * 100 // len(palabras_a_generar)}% completado.")
        cantidad_actual = random.randint(1, maximo_palabras_imagen)
        cantidad_actual = min(cantidad_actual, len(palabras_a_generar) - index_actual)
        palabras_actuales = palabras_a_generar.iloc[index_actual : index_actual + cantidad_actual].reset_index(drop=True)
        fuentes_actuales = ''
        for idx, row in palabras_actuales.iterrows():
            fuentes_actuales += f"{row['font_name']}"
            if idx < len(palabras_actuales) - 1:
                fuentes_actuales += ', '
        img_cv2, bboxes, caracteres, palabras_a_generar = generar_imagen_multifuente(palabras_actuales, palabras_a_generar, tamanio_imagen, rango_separacion_caracteres, rango_separacion_lineas, rango_tamanio_fuente)
        info_imagenes.append({'labels':caracteres,'fuentes':fuentes_actuales,'index':index_imagen})
        data_imagenes.append({'imagen':img_cv2,'bboxes':bboxes,'index':index_imagen})
        index_actual += cantidad_actual
        index_imagen += 1
    print(f"total: {index_imagen} imagenes generadas")
# Out:
# Total de palabras a generar: 193136
# 0% completado.
# 0% completado.
# 1% completado.
# 3% completado.
# 4% completado.
# 5% completado.
# 6% completado.
# 7% completado.
# 8% completado.
# 8% completado.
# 9% completado.
# 9% completado.
# 10% completado.
# 13% completado.
# 13% completado.
# 16% completado.
# 16% completado.
# 18% completado.
# 18% completado.
# 19% completado.
# 19% completado.
# 20% completado.
# 20% completado.
# 21% completado.
# 22% completado.
# 23% completado.
# 23% completado.
# 24% completado.
# 25% completado.
# 28% completado.
# 28% completado.
# 29% completado.
# 30% completado.
# 32% completado.
# 32% completado.
# 33% completado.
# 33% completado.
# 34% completado.
# 35% completado.
# palabra exedida del ancho: kRKs - fuente: Diplomata-regular
# palabra exedida del ancho: kRKs - fuente: Diplomata-regular
# 37% completado.
# 37% completado.
# 38% completado.
# 38% completado.
# 40% completado.
# 41% completado.
# 41% completado.
# 44% completado.
# 44% completado.
# 45% completado.
# 46% completado.
# 48% completado.
# 49% completado.
# palabra exedida del ancho: THMb - fuente: BioRhyme_Expanded-800
# palabra exedida del ancho: THMb - fuente: BioRhyme_Expanded-800
# 50% completado.
# palabra exedida del ancho: B6JQ - fuente: Asset-regular
# palabra exedida del ancho: B6JQ - fuente: Asset-regular
# 51% completado.
# 52% completado.
# 52% completado.
# 53% completado.
# 54% completado.
# 55% completado.
# 55% completado.
# 56% completado.
# 57% completado.
# 58% completado.
# 59% completado.
# 60% completado.
# 62% completado.
# 62% completado.
# 63% completado.
# 65% completado.
# 67% completado.
# 68% completado.
# 70% completado.
# 71% completado.
# 72% completado.
# 73% completado.
# 75% completado.
# 75% completado.
# 76% completado.
# 76% completado.
# 78% completado.
# 81% completado.
# 81% completado.
# 82% completado.
# 83% completado.
# 83% completado.
# 85% completado.
# palabra exedida del ancho: R9os - fuente: Diplomata_SC-regular
# 86% completado.
# 87% completado.
# 88% completado.
# 89% completado.
# 90% completado.
# 91% completado.
# 92% completado.
# 93% completado.
# 94% completado.
# 94% completado.
# 95% completado.
# 96% completado.
# 97% completado.
# 97% completado.
# 98% completado.
# palabra exedida del ancho: odOM - fuente: Asset-regular
# palabra exedida del ancho: odOM - fuente: Asset-regular
# 99% completado.
# total: 96613 imagenes generadas

# %%
pandas_dataset = pd.DataFrame(info_imagenes)
numpy_dataset = np.array(data_imagenes)
muestra = pandas_dataset.sample(20)
for index, row in muestra.iterrows():
    print(f"Index: {row['index']}, Letras: {row['labels']}, Fuente: {row['fuentes']}")
    img_muestra = numpy_dataset[row['index']]['imagen']
    bboxes= numpy_dataset[row['index']]['bboxes']
    for bbox in bboxes:
        cv2.rectangle(img_muestra, (bbox[0], bbox[1]), (bbox[2], bbox[3]), (128, 128, 128), 1)
    plt.imshow(img_muestra, cmap='gray')
    plt.show()
    print("\n")
# Out:
# Index: 50178, Letras: ['X', 'i', 'W', 'k', 'r'], Fuente: Fira_Sans_Condensed-900, Merienda-800, Fredoka-600
# Index: 32415, Letras: ['R', '4', '7'], Fuente: Lexend_Peta-800
# Index: 95115, Letras: ['Y', 'Z', 'j', '9'], Fuente: Ancizar_Sans-700italic
# Index: 20975, Letras: ['X', 'U', 'c', 'q', 'e'], Fuente: Gentium_Book_Plus-700, DM_Mono-italic
# Index: 82401, Letras: ['7', 'E', 'n', 'G', 'L', '6', 'i'], Fuente: Lexend-500, Kanit-300
# Index: 90157, Letras: ['Y', 'z', 'C', '6', 'k', 'o', 'C', 'm', 'D', 'u'], Fuente: Mona_Sans-200italic, M_PLUS_1-600, Cabin-500
# Index: 19999, Letras: ['S', '9', 'l', 'n', '6', 'v', 'j', 'x', 'h'], Fuente: Noto_Sans_Gujarati-600, Cuprum-italic, Gemunu_Libre-300
# Index: 91643, Letras: ['D'], Fuente: DynaPuff-700
# Index: 85497, Letras: ['Y', 'y', 'h', '0', 'V', 'U', 'Q'], Fuente: Noto_Sans_Bassa_Vah-700, Ancizar_Serif-800
# Index: 54979, Letras: ['t'], Fuente: Arimo-600italic
# Index: 27709, Letras: ['s', '7', 'i', '3', 'a', 's'], Fuente: Cascadia_Code-500italic, Cascadia_Mono-500italic, Ancizar_Serif-500
# Index: 93994, Letras: ['f', 'w', 'L', 'e', 'W', 'z'], Fuente: Libre_Baskerville-italic, Albert_Sans-600italic, Gluten-100
# Index: 81154, Letras: ['O', 'Y', 'C', 'w', 'Y', 's', 'o'], Fuente: McLaren-regular, Italianno-regular
# Index: 76165, Letras: ['4'], Fuente: Epilogue-600italic
# Index: 72995, Letras: ['H', 'a', 'J', 'T', 'm', 'V'], Fuente: Lexend_Peta-800, Anaheim-700, Labrada-900italic
# Index: 31118, Letras: ['m', 'L', 'R', 'V'], Fuente: Finlandica-700
# Index: 12637, Letras: ['M'], Fuente: Chivo-600italic
# Index: 37696, Letras: ['n', 'q', 'd', '8', 'C', 'J', 'r', 'c', 'M', '8', 'H'], Fuente: Comic_Relief-700, Figtree-500, Kode_Mono-regular
# Index: 38432, Letras: ['y', 'v', '9', '6', 'v', '9'], Fuente: IBM_Plex_Sans-700, IBM_Plex_Mono-500italic
# Index: 22632, Letras: ['r', 'T', 't', 's', 'P', 'f', 'x', 'H', 'L'], Fuente: IBM_Plex_Sans_KR-300, Baloo_Da_2-regular, Edu_AU_VIC_WA_NT_Guides-700

# %%
# Crear el directorio si no existe
os.makedirs(carpeta_destino_datasets, exist_ok=True)

# Guardar el dataset de imágenes (arrays numpy) como archivo .npy
numpy_output_path = os.path.join(carpeta_destino_datasets, 'imagenes_dataset.npy')
np.save(numpy_output_path, numpy_dataset)
print(f"Dataset de imágenes guardado en: {numpy_output_path}")

# Guardar el dataset de información (pandas DataFrame) como archivo .csv
pandas_output_path = os.path.join(carpeta_destino_datasets, 'info_imagenes.csv')
pandas_dataset.to_csv(pandas_output_path, index=False)
print(f"Dataset de información guardado en: {pandas_output_path}")
# Out:
# Dataset de imágenes guardado en: /content/datasets/imagenes_dataset.npy
# Dataset de información guardado en: /content/datasets/info_imagenes.csv
