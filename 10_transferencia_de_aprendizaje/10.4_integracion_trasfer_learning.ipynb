# %% [markdown]
# # Modelo VGG16 Preentrenado para Clasificación de Imágenes
#
# ## Introducción
# En esta lección, aprenderemos a usar el modelo VGG16 preentrenado para la tarea de clasificación de imágenes. VGG16 es una arquitectura profunda de red neuronal que demostró ser efectiva para reconocer imágenes.
#
# ## Objetivo
# El objetivo de este cuaderno es construir un modelo de clasificación de imágenes que clasifique imágenes de gatos y perros utilizando transfer learning.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/letras/letras.zip -d /content/letras/

# %%
# Importamos TensorFlow, la principal biblioteca para Deep Learning
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.applications import VGG16 # Para cargar el modelo VGG16
from tensorflow.keras.preprocessing import image # Para cargar imágenes
from tensorflow.keras.models import Model # Para construir nuestro nuevo modelo
from tensorflow.keras.layers import Dense, Flatten # Para añadir capas a nuestro modelo
import numpy as np # Para manipular arreglos de números
import matplotlib.pyplot as plt # Para mostrar imágenes

# %% [markdown]
# ##Carga del Modelo VGG16

# %%
# Cargamos el modelo VGG16 preentrenado en el conjunto de datos ImageNet.
# 'weights="imagenet"': Usa los pesos entrenados en ImageNet.
# 'include_top=False': Quitamos la capa final de clasificación para que podamos añadir la nuestra.
# 'input_shape=(224, 224, 3)': Le decimos al modelo el tamaño de las imágenes que va a esperar (altura, anchura, canales de color RGB).
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Opcional: Mostramos un resumen del modelo para ver sus capas (no es necesario entenderlo todo)
# base_model.summary()
print("Modelo VGG16 cargado exitosamente. Es la 'base de conocimiento' de nuestro experto.")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# Modelo VGG16 cargado exitosamente. Es la 'base de conocimiento' de nuestro experto.

# %% [markdown]
# ##Preparación del Modelo

# %%
# Congelamos las capas del modelo base para que no se reentrenen.
# Así, solo ajustaremos las nuevas capas que añadiremos.
base_model.trainable = False
print("Capas del modelo base congeladas. ¡Listo para añadir nuestra parte específica!")
# Out:
# Capas del modelo base congeladas. ¡Listo para añadir nuestra parte específica!

# %%
# Creamos una nueva capa que 'aplanará' la salida del modelo base.
# Esto es como tomar toda la información visual del experto y convertirla en una lista de números.
x = Flatten()(base_model.output)

# Añadimos una capa densa (o completamente conectada) con activación 'relu'.
# Esta capa aprenderá patrones complejos de la información aplanada.
x = Dense(256, activation='relu')(x)

# Añadimos la capa final de salida.
# Si tenemos 2 clases (ej. perro/gato), usaremos 'Dense(2)' y activación 'sigmoid' (para clasificación binaria).
# Si tuviéramos N clases (ej. perro, gato, pájaro, caballo), usaríamos 'Dense(N)' y activación 'softmax'.
output = Dense(2, activation='sigmoid')(x) # Asumiendo 2 clases: Perro y Gato

# Creamos el modelo final, combinando el modelo base y nuestras nuevas capas.
model = Model(inputs=base_model.input, outputs=output)

print("Nuevas capas añadidas. ¡Nuestro experto ya tiene una nueva 'cabeza' para nuestra tarea!")
# model.summary() # Puedes descomentar para ver el resumen del modelo completo
# Out:
png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/14957.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/14958.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/14959.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1495.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/14960.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/14961.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/14962.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/14963.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/14964.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/14965.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/14966.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/14967.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/14968.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/14969.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1496.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/14970.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/14971.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/14972.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/14973.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/14974.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/14975.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/14976.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/14977.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/14978.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/14979.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1497.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/14980.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/14981.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/14982.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/14983.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/14984.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/14985.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/14986.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/14987.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/14988.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/14989.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1498.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/14990.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1499.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/149.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/14.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1500.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1501.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1502.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1503.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1504.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1505.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1506.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1507.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1508.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1509.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/150.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1510.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1511.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1512.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1513.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1514.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1515.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1516.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1517.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1518.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1519.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/151.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1520.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1521.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1522.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1523.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1524.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1525.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1526.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1527.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1528.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1529.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/152.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1530.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1531.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1532.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1533.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1534.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1535.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1536.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1537.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1538.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1539.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/153.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1540.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1541.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1542.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1543.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1544.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1545.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1546.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1547.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1548.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1549.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/154.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1550.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1551.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1552.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1553.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1554.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1555.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1556.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1557.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1558.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1559.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/155.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1560.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1561.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1562.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1563.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1564.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1565.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1566.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1567.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1568.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1569.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/156.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1570.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1571.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1572.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1573.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1574.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1575.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1576.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1577.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1578.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1579.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/157.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1580.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1581.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1582.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1583.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1584.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1585.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1586.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1587.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1589.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/158.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/15.png': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/letras/C/1.png': No such file or directory

# %%
# Definimos el tamaño de las imágenes que VGG16 espera
IMG_HEIGHT = 224
IMG_WIDTH = 224
BATCH_SIZE = 32 # Número de imágenes que procesaremos a la vez (puedes probar con 4 o 8 si tu dataset es muy pequeño)

# Cargamos las imágenes desde nuestras carpetas.
# 'labels="inferred"' significa que Keras deduce las etiquetas de los nombres de las carpetas.
# 'image_size' redimensiona las imágenes.
# 'batch_size' para procesar en grupos.
train_ds = tf.keras.utils.image_dataset_from_directory(
    './data/train',
    labels='inferred',
    image_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE
)

print(f"Dataset de entrenamiento cargado. Clases encontradas: {train_ds.class_names}")

# Opcional: Visualiza algunas imágenes del dataset para verificar
# plt.figure(figsize=(10, 10))
# for images, labels in train_ds.take(1):
#     for i in range(min(9, len(images))): # Muestra hasta 9 imágenes
#         ax = plt.subplot(3, 3, i + 1)
#         plt.imshow(images[i].numpy().astype("uint8"))
#         plt.title(train_ds.class_names[labels[i]])
#         plt.axis("off")
# plt.show()
# Out:
# Found 0 files belonging to 3 classes.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-c9cc85de22f5> in <cell line: 0>()
#       8 # 'image_size' redimensiona las imágenes.
#       9 # 'batch_size' para procesar en grupos.
# ---> 10 train_ds = tf.keras.utils.image_dataset_from_directory(
#      11     './data/train',
#      12     labels='inferred',
#
# /usr/local/lib/python3.11/dist-packages/keras/src/utils/image_dataset_utils.py in image_dataset_from_directory(directory, labels, label_mode, class_names, color_mode, batch_size, image_size, shuffle, seed, validation_split, subset, interpolation, follow_links, crop_to_aspect_ratio, pad_to_aspect_ratio, data_format, verbose)
#     327         )
#     328         if not image_paths:
# --> 329             raise ValueError(
#     330                 f"No images found in directory {directory}. "
#     331                 f"Allowed formats: {ALLOWLIST_FORMATS}"
#
# ValueError: No images found in directory ./data/train. Allowed formats: ('.bmp', '.gif', '.jpeg', '.jpg', '.png')

# %% [markdown]
#  ## Compilación y Entrenamiento del Modelo

# %%
# Compilamos el modelo.
# 'optimizer="adam"': El algoritmo que ajustará los pesos de las capas nuevas.
# 'loss="binary_crossentropy"': La función que mide qué tan bien lo está haciendo el modelo (para 2 clases).
# 'metrics=["accuracy"]': La métrica que queremos ver durante el entrenamiento (qué tan preciso es).
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

print("Modelo compilado y listo para entrenar.")

# %%
# Entrenamos el modelo.
# 'train_ds': Nuestros datos de entrenamiento.
# 'epochs=5': El número de veces que el modelo verá todo el dataset.
# ¡Experimenten con el número de epochs!
history = model.fit(train_ds, epochs=5)

print("\nEntrenamiento finalizado.")

# %% [markdown]
# ##Evaluación del Modelo

# %%
# URL de una imagen de prueba (pueden cambiarla por una propia que suban a Colab)
# Ejemplo: una URL de una imagen de gato o perro que encuentren online
img_url = "https://upload.wikimedia.org/wikipedia/commons/thumb/1/15/Cat_August_2010-4.jpg/1200px-Cat_August_2010-4.jpg" # URL de un gato
# img_url = "https://upload.wikimedia.org/wikipedia/commons/thumb/a/a2/Canis_lupus_familiaris_%28dog%29.jpg/1200px-Canis_lupus_familiaris_%28dog%29.jpg" # URL de un perro

# Descargamos la imagen (si es una URL) o la cargamos localmente
try:
    img_path = tf.keras.utils.get_file('test_image.jpg', origin=img_url)
except Exception:
    print("No se pudo descargar la imagen, asegúrate que la URL es correcta.")
    # O si ya la subieron manualmente a Colab, usen su ruta:
    # img_path = '/content/tu_imagen_test.jpg' # Ajusta esta ruta

# Cargamos la imagen y la redimensionamos al tamaño esperado por el modelo
img = image.load_img(img_path, target_size=(IMG_HEIGHT, IMG_WIDTH))
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0) # Añadimos una dimensión extra para el batch
img_array /= 255.0 # Normalizamos los valores de píxeles (0-1)

# Realizamos la predicción
predictions = model.predict(img_array)

# Mostramos la imagen y la predicción
plt.imshow(img)
plt.axis('off')

class_names = train_ds.class_names # Las clases que encontró tu dataset (ej. ['cats', 'dogs'])

# Interpretamos la predicción
# Si tienes 2 clases y sigmoid, la salida es un valor entre 0 y 1.
# Si es >0.5 es la clase 1, si es <0.5 es la clase 0.
predicted_class_index = (predictions[0] > 0.5).astype(int)[0]
predicted_class_name = class_names[predicted_class_index]
confidence = predictions[0][0] if predicted_class_index == 1 else (1 - predictions[0][0])

plt.title(f"Predicción: {predicted_class_name} (Confianza: {confidence:.2f})")
plt.show()

print(f"Predicción numérica (es un valor entre 0 y 1 para la primera clase): {predictions[0]}")
print(f"Clases del dataset: {class_names}")
